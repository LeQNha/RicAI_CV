# %%
import sys
import tensorflow as tf
import keras
# Out:
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print("Python version:", sys.version)
print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)
# Out:
# Python version: 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# TensorFlow version: 2.15.0
# Keras version: 2.15.0

# %%
print(tf)
print(tf.__file__)
# Out:
# <module 'tensorflow' from 'C:\\Users\\qahhn\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\tensorflow\\__init__.py'>
# C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py
