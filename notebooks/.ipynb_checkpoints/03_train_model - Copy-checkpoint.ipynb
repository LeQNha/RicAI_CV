# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.applications import MobileNetV2
import os

import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.18.0
# GPU available: []

# %%
# DATA_DIR = "data/split"
DATA_DIR = "../data/split"

IMG_SIZE = (224, 224)
BATCH_SIZE = 64
EPOCHS = 40

# %%
# train_gen = ImageDataGenerator(
#     rescale=1./255,
#     rotation_range=20,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     zoom_range=0.2,
#     horizontal_flip=True
# )

# val_gen = ImageDataGenerator(rescale=1./255)

train_gen = ImageDataGenerator(
    rescale=1./255,
    
    # Geometric transformations
    rotation_range=40,           # 20 -> 40 (xoay mạnh hơn)
    width_shift_range=0.2,       # 0.1 -> 0.2 (dịch ngang)
    height_shift_range=0.2,      # 0.1 -> 0.2 (dịch dọc)
    shear_range=0.2,             # (biến dạng)
    zoom_range=0.3,              # 0.2 → 0.3 (zoom)
    horizontal_flip=True,
    vertical_flip=True,          # (lật dọc)
    
    # Color/brightness augmentation
    brightness_range=[0.7, 1.3], # Thay đổi độ sáng ±30%
    fill_mode='nearest'          # Cách fill pixel khi transform
)

val_gen = ImageDataGenerator(rescale=1./255)

val_gen = ImageDataGenerator(rescale=1./255)

print(" Augmentation config:")
print("  - Rotation: ±40°")
print("  - Shift: ±20%")
print("  - Zoom: ±30%")
print("  - Brightness: ±30%")
print("  - Flips: horizontal + vertical")
# Out:
#  Augmentation config:
#   - Rotation: ±40°
#   - Shift: ±20%
#   - Zoom: ±30%
#   - Brightness: ±30%
#   - Flips: horizontal + vertical

# %%
train_data = train_gen.flow_from_directory(
    os.path.join(DATA_DIR, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

val_data = val_gen.flow_from_directory(
    os.path.join(DATA_DIR, "val"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)
# Out:
# Found 18510 images belonging to 11 classes.
# Found 3968 images belonging to 11 classes.

# %%
# # Đếm số samples mỗi class
# class_counts = {}
# for class_name, class_idx in train_data.class_indices.items():
#     class_dir = os.path.join(DATA_DIR, "train", class_name)
#     count = len(os.listdir(class_dir))
#     class_counts[class_idx] = count

# print("Class distribution:")
# for class_name, class_idx in sorted(train_data.class_indices.items(), key=lambda x: x[1]):
#     print(f"  {class_name:25s}: {class_counts[class_idx]:5d} samples")

# # Tính class weights (cân bằng tự động)
# classes = np.array(list(class_counts.keys()))
# samples = np.array(list(class_counts.values()))

# class_weights = compute_class_weight(
#     class_weight='balanced',
#     classes=classes,
#     y=np.repeat(classes, samples)  # Tạo array với số lượng tương ứng
# )

# # Convert to dict
# class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

# print("\nClass weights (higher = more important):")
# for class_name, class_idx in sorted(train_data.class_indices.items(), key=lambda x: x[1]):
#     print(f"  {class_name:25s}: {class_weight_dict[class_idx]:.3f}")

# Đếm số samples mỗi class trong train set
class_counts = {}
for class_name, class_idx in train_data.class_indices.items():
    class_dir = os.path.join(DATA_DIR, "train", class_name)
    count = len([f for f in os.listdir(class_dir) if f.endswith(('.jpg', '.jpeg', '.png'))])
    class_counts[class_idx] = count

print("\n" + "="*70)
print("CLASS DISTRIBUTION (Training Set)")
print("="*70)

total_samples = sum(class_counts.values())
for class_name, class_idx in sorted(train_data.class_indices.items(), key=lambda x: x[1]):
    count = class_counts[class_idx]
    percentage = count / total_samples * 100
    bar = "█" * int(percentage / 2)  # Visual bar
    print(f"{class_name:25s}: {count:5d} ({percentage:5.1f}%) {bar}")

# Tính class weights tự động (cân bằng)
classes = np.array(list(class_counts.keys()))
samples = np.array(list(class_counts.values()))

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=np.repeat(classes, samples)
)

# Convert to dict
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

print("\n" + "="*70)
print("CLASS WEIGHTS (Higher = More Important)")
print("="*70)
for class_name, class_idx in sorted(train_data.class_indices.items(), key=lambda x: x[1]):
    weight = class_weight_dict[class_idx]
    stars = "x" * int(weight * 2)  # Visual indicator
    print(f"{class_name:25s}: {weight:6.3f} {stars}")

print("\n Classes với ít samples sẽ có weight cao hơn")
print("   → Model sẽ chú ý nhiều hơn vào những class này khi training")
# Out:
# ======================================================================
# CLASS DISTRIBUTION (Training Set)
# ======================================================================
# bacterial_blight         :  2347 ( 13.6%) ██████
# barrow_brown_leaf_spot   :   749 (  4.3%) ██
# brown_spot               :  3285 ( 19.0%) █████████
# healthy                  :  2368 ( 13.7%) ██████
# leaf_blast               :  3215 ( 18.6%) █████████
# leaf_scald               :  1504 (  8.7%) ████
# leaf_smut                :    17 (  0.1%)
# neck_blast               :   700 (  4.0%) ██
# rice_hispa               :  1059 (  6.1%) ███
# sheath_blight            :  1772 ( 10.2%) █████
# tungro                   :   299 (  1.7%)
#
# ======================================================================
# CLASS WEIGHTS (Higher = More Important)
# ======================================================================
# bacterial_blight         :  0.671 x
# barrow_brown_leaf_spot   :  2.102 xxxx
# brown_spot               :  0.479
# healthy                  :  0.665 x
# leaf_blast               :  0.490
# leaf_scald               :  1.047 xx
# leaf_smut                : 92.594 xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# neck_blast               :  2.249 xxxx
# rice_hispa               :  1.486 xx
# sheath_blight            :  0.888 x
# tungro                   :  5.265 xxxxxxxxxx
#
#  Classes với ít samples sẽ có weight cao hơn
#    → Model sẽ chú ý nhiều hơn vào những class này khi training

# %%
print("Label mapping:")
print(train_data.class_indices)
# Out:
# Label mapping:
# {'bacterial_blight': 0, 'barrow_brown_leaf_spot': 1, 'brown_spot': 2, 'healthy': 3, 'leaf_blast': 4, 'leaf_scald': 5, 'leaf_smut': 6, 'neck_blast': 7, 'rice_hispa': 8, 'sheath_blight': 9, 'tungro': 10}

# %%
base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False  # ❗ rất quan trọng

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(train_data.num_classes, activation="softmax")
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 7, 7, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 11)                  │           1,419 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,423,371 (9.24 MB)
#  Trainable params: 165,387 (646.04 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# history = model.fit(
#     train_data,
#     validation_data=val_data,
#     epochs=EPOCHS
# )

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS,
    class_weight=class_weight_dict  # THÊM DÒNG NÀY
)

print("\n Training hoàn tất với class weights!")
# Out:
# C:\Users\qahhn\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 494s 2s/step - accuracy: 0.1913 - loss: 2.5535 - val_accuracy: 0.4141 - val_loss: 1.6634
# Epoch 2/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.3720 - loss: 1.5786 - val_accuracy: 0.5010 - val_loss: 1.3795
# Epoch 3/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 485s 2s/step - accuracy: 0.4559 - loss: 1.3011 - val_accuracy: 0.5345 - val_loss: 1.2724
# Epoch 4/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 482s 2s/step - accuracy: 0.4993 - loss: 1.1346 - val_accuracy: 0.5711 - val_loss: 1.1828
# Epoch 5/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 475s 2s/step - accuracy: 0.5356 - loss: 1.0710 - val_accuracy: 0.5938 - val_loss: 1.1380
# Epoch 6/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 445s 2s/step - accuracy: 0.5343 - loss: 1.0223 - val_accuracy: 0.6207 - val_loss: 1.0696
# Epoch 7/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 414s 1s/step - accuracy: 0.5700 - loss: 0.9441 - val_accuracy: 0.6457 - val_loss: 1.0179
# Epoch 8/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 411s 1s/step - accuracy: 0.5854 - loss: 0.9159 - val_accuracy: 0.6593 - val_loss: 0.9682
# Epoch 9/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 411s 1s/step - accuracy: 0.5864 - loss: 0.9136 - val_accuracy: 0.6689 - val_loss: 0.9406
# Epoch 10/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 408s 1s/step - accuracy: 0.6029 - loss: 0.8667 - val_accuracy: 0.6648 - val_loss: 0.9500
# Epoch 11/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 410s 1s/step - accuracy: 0.6165 - loss: 0.8181 - val_accuracy: 0.6935 - val_loss: 0.8817
# Epoch 12/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6157 - loss: 0.8292 - val_accuracy: 0.6956 - val_loss: 0.8633
# Epoch 13/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 410s 1s/step - accuracy: 0.6342 - loss: 0.7754 - val_accuracy: 0.6961 - val_loss: 0.8717
# Epoch 14/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6305 - loss: 0.7912 - val_accuracy: 0.7074 - val_loss: 0.8361
# Epoch 15/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 411s 1s/step - accuracy: 0.6448 - loss: 0.7756 - val_accuracy: 0.7102 - val_loss: 0.8287
# Epoch 16/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6374 - loss: 0.7612 - val_accuracy: 0.7140 - val_loss: 0.8265
# Epoch 17/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 410s 1s/step - accuracy: 0.6491 - loss: 0.7399 - val_accuracy: 0.7251 - val_loss: 0.7902
# Epoch 18/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 410s 1s/step - accuracy: 0.6571 - loss: 0.7252 - val_accuracy: 0.7248 - val_loss: 0.7814
# Epoch 19/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 411s 1s/step - accuracy: 0.6685 - loss: 0.7022 - val_accuracy: 0.7283 - val_loss: 0.7764
# Epoch 20/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 417s 1s/step - accuracy: 0.6583 - loss: 0.7477 - val_accuracy: 0.7351 - val_loss: 0.7617
# Epoch 21/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 413s 1s/step - accuracy: 0.6726 - loss: 0.6881 - val_accuracy: 0.7281 - val_loss: 0.7680
# Epoch 22/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 411s 1s/step - accuracy: 0.6784 - loss: 0.6873 - val_accuracy: 0.7447 - val_loss: 0.7291
# Epoch 23/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6722 - loss: 0.6834 - val_accuracy: 0.7445 - val_loss: 0.7304
# Epoch 24/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 410s 1s/step - accuracy: 0.6840 - loss: 0.6601 - val_accuracy: 0.7404 - val_loss: 0.7362
# Epoch 25/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6867 - loss: 0.6492 - val_accuracy: 0.7475 - val_loss: 0.7273
# Epoch 26/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6889 - loss: 0.6469 - val_accuracy: 0.7596 - val_loss: 0.6942
# Epoch 27/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6968 - loss: 0.6324 - val_accuracy: 0.7530 - val_loss: 0.7057
# Epoch 28/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 410s 1s/step - accuracy: 0.6949 - loss: 0.6381 - val_accuracy: 0.7308 - val_loss: 0.7681
# Epoch 29/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6939 - loss: 0.6589 - val_accuracy: 0.7513 - val_loss: 0.7008
# Epoch 30/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 408s 1s/step - accuracy: 0.6959 - loss: 0.6496 - val_accuracy: 0.7634 - val_loss: 0.6780
# Epoch 31/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.6964 - loss: 0.6240 - val_accuracy: 0.7613 - val_loss: 0.6769
# Epoch 32/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 408s 1s/step - accuracy: 0.7075 - loss: 0.6047 - val_accuracy: 0.7497 - val_loss: 0.7166
# Epoch 33/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 411s 1s/step - accuracy: 0.7041 - loss: 0.6028 - val_accuracy: 0.7634 - val_loss: 0.6608
# Epoch 34/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.7087 - loss: 0.6127 - val_accuracy: 0.7671 - val_loss: 0.6620
# Epoch 35/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 408s 1s/step - accuracy: 0.7118 - loss: 0.5910 - val_accuracy: 0.7704 - val_loss: 0.6504
# Epoch 36/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - accuracy: 0.7113 - loss: 0.5953 - val_accuracy: 0.7702 - val_loss: 0.6430
# Epoch 37/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 410s 1s/step - accuracy: 0.7191 - loss: 0.5781 - val_accuracy: 0.7707 - val_loss: 0.6467
# Epoch 38/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 408s 1s/step - accuracy: 0.7241 - loss: 0.5790 - val_accuracy: 0.7752 - val_loss: 0.6457
# Epoch 39/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 407s 1s/step - accuracy: 0.7193 - loss: 0.5835 - val_accuracy: 0.7800 - val_loss: 0.6224
# Epoch 40/40
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 412s 1s/step - accuracy: 0.7206 - loss: 0.5830 - val_accuracy: 0.7828 - val_loss: 0.6214
#
#  Training hoàn tất với class weights!

# %%
# os.makedirs("models", exist_ok=True)

# model.save("models/rice_disease_classifier.h5")
# print("✅ Model saved!")

os.makedirs("../models", exist_ok=True)
model.save("../models/rice_disease_classifier.h5")
print("Model saved!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved!

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.legend()
plt.title("Training Accuracy")
plt.show()
