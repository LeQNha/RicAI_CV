# %% [markdown]
# # 09 - Train YOLOv8n
# Train YOLOv8n để detect lá lúa (bounding box)

# %%
# Cài đặt ultralytics nếu chưa có
# !pip install ultralytics

# %%
import os
import torch
from pathlib import Path
from ultralytics import YOLO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Config
DATA_YAML   = "../data/yolo_dataset/data.yaml"
MODEL_SIZE  = "yolov8n.pt"   # nano – nhẹ nhất, phù hợp mobile
EPOCHS      = 50
IMG_SIZE    = 640
BATCH_SIZE  = 16
PROJECT_DIR = "../models/yolo"
RUN_NAME    = "rice_leaf_detect"

print(f"Device : {'GPU ' + torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")
print(f"Data   : {os.path.abspath(DATA_YAML)}")
# Out:
# Device : CPU
# Data   : D:\Python Projects\RicAI_CV\ric_cv\data\yolo_dataset\data.yaml

# %%
# ── 1. Load pretrained YOLOv8n ────────────────────────────────────────
model = YOLO(MODEL_SIZE)
print(f" Loaded {MODEL_SIZE}")
# Out:
#  Loaded yolov8n.pt

# %%
# FIX ID .TXT
BASE_LABEL_DIR = "../data/yolo_dataset/labels"

for split in ["train", "val", "test"]:
    label_dir = os.path.join(BASE_LABEL_DIR, split)
    
    if not os.path.exists(label_dir):
        continue
    
    for file in os.listdir(label_dir):
        path = os.path.join(label_dir, file)
        
        with open(path, "r") as f:
            lines = f.readlines()
        
        new_lines = []
        for line in lines:
            parts = line.strip().split()
            if len(parts) == 5:
                parts[0] = "0"  # fix class id
                new_lines.append(" ".join(parts))
        
        with open(path, "w") as f:
            f.write("\n".join(new_lines))

print("✅ Fixed ALL labels (train/val/test)")
# Out:
# ✅ Fixed ALL labels (train/val/test)

# %%
# ── 2. Train ──────────────────────────────────────────────────────────
results = model.train(
    data      = DATA_YAML,
    epochs    = EPOCHS,
    imgsz     = IMG_SIZE,
    batch     = BATCH_SIZE,
    project   = PROJECT_DIR,
    name      = RUN_NAME,
    exist_ok  = True,
    patience  = 15,          # Early stopping
    save      = True,
    plots     = True,
    
    # Augmentation (nhẹ - ảnh đã augment)
    hsv_h     = 0.015,
    hsv_s     = 0.7,
    hsv_v     = 0.4,
    degrees   = 10.0,
    translate = 0.1,
    scale     = 0.5,
    fliplr    = 0.5,
    flipud    = 0.2,
    mosaic    = 0.5,
)

print("\n Training complete!")
# Out:
# Ultralytics 8.4.37  Python-3.12.2 torch-2.5.1+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# ...

# %%
print(results.save_dir)
# Out:
# D:\Python Projects\RicAI_CV\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect

# %%
# ── 3. Đường dẫn model tốt nhất ───────────────────────────────────────
best_model_path = os.path.join(PROJECT_DIR, RUN_NAME, 'weights', 'best.pt')
print(f"Best model: {best_model_path}")
print(f"Exists    : {os.path.exists(best_model_path)}")
# Out:
# Best model: ../models/yolo\rice_leaf_detect\weights\best.pt
# Exists    : True

# %%
# ── 4. Validate ───────────────────────────────────────────────────────
best_model = YOLO(best_model_path)
metrics = best_model.val(data=DATA_YAML)

print("\n" + "="*60)
print("VALIDATION METRICS")
print("="*60)
print(f"mAP50         : {metrics.box.map50:.4f}")
print(f"mAP50-95      : {metrics.box.map:.4f}")
print(f"Precision     : {metrics.box.mp:.4f}")
print(f"Recall        : {metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.4.37  Python-3.12.2 torch-2.5.1+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 593.4721.0 MB/s, size: 80.9 KB)
# val: Scanning D:\Python Projects\RicAI_CV\ric_cv\data\yolo_dataset\labels\val.cache... 226 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 226/226  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 1.2s/it 17.7s1.2s
#                    all        226        244      0.932      0.865      0.927      0.682
# Speed: 1.6ms preprocess, 70.6ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to D:\Python Projects\RicAI_CV\ric_cv\notebooks\runs\detect\val
#
# ...
# VALIDATION METRICS
# ...
# mAP50         : 0.9266
# mAP50-95      : 0.6818
# Precision     : 0.9322
# Recall        : 0.8648

# %%
# ── 5. Hiển thị biểu đồ training ──────────────────────────────────────
results_dir = os.path.join(PROJECT_DIR, RUN_NAME)
plot_files = ['results.png', 'confusion_matrix.png', 'val_batch0_pred.jpg']

for plot_file in plot_files:
    path = os.path.join(results_dir, plot_file)
    if os.path.exists(path):
        img = mpimg.imread(path)
        plt.figure(figsize=(12, 6))
        plt.imshow(img)
        plt.title(plot_file)
        plt.axis('off')
        plt.show()
    else:
        print(f"  {plot_file} not found")

# %%
# ── 6. Export sang ONNX (optional - để dùng cross-platform) ───────────
# best_model.export(format='onnx')
# print("✅ Exported to ONNX")

# ── 7. Copy best.pt ra thư mục models chính ───────────────────────────
import shutil
os.makedirs("../models", exist_ok=True)
dst = "../models/yolov8n_rice_leaf.pt"
shutil.copy(best_model_path, dst)
print(f" Saved best model -> {dst}")

print("\n READY for 10_apply_yolo_crop_all.ipynb")
# Out:
#  Saved best model -> ../models/yolov8n_rice_leaf.pt
#
#  READY for 10_apply_yolo_crop_all.ipynb
