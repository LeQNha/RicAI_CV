# %%
# Cài đặt ultralytics nếu chưa có
# !pip install ultralytics

# %%
import os
import torch
from pathlib import Path
from ultralytics import YOLO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Config
DATA_YAML   = "../data/yolo_dataset/data.yaml"
MODEL_SIZE  = "yolov8n.pt" 
EPOCHS      = 50
IMG_SIZE    = 640
BATCH_SIZE  = 16
PROJECT_DIR = "../models/yolo"
RUN_NAME    = "rice_leaf_detect"

print(f"Device : {'GPU ' + torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")
print(f"Data   : {os.path.abspath(DATA_YAML)}")
# Out:
# Device : CPU
# Data   : D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\data.yaml

# %%
# 1. Load pretrained YOLOv8n
model = YOLO(MODEL_SIZE)
print(f" Loaded {MODEL_SIZE}")
# Out:
#  Loaded yolov8n.pt

# %%
# FIX ID .TXT
BASE_LABEL_DIR = "../data/yolo_dataset/labels"

for split in ["train", "val", "test"]:
    label_dir = os.path.join(BASE_LABEL_DIR, split)
    
    if not os.path.exists(label_dir):
        continue
    
    for file in os.listdir(label_dir):
        path = os.path.join(label_dir, file)
        
        with open(path, "r") as f:
            lines = f.readlines()
        
        new_lines = []
        for line in lines:
            parts = line.strip().split()
            if len(parts) == 5:
                parts[0] = "0"  # fix class id
                new_lines.append(" ".join(parts))
        
        with open(path, "w") as f:
            f.write("\n".join(new_lines))

print(" Fixed ALL labels (train/val/test)")
# Out:
#  Fixed ALL labels (train/val/test)

# %%
# 2. Train
results = model.train(
    data      = DATA_YAML,
    epochs    = EPOCHS,
    imgsz     = IMG_SIZE,
    batch     = BATCH_SIZE,
    project   = PROJECT_DIR,
    name      = RUN_NAME,
    exist_ok  = True,
    patience  = 15,          # Early stopping
    save      = True,
    plots     = True,
    
    # Augmentation (nhẹ - ảnh đã augment)
    hsv_h     = 0.015,
    hsv_s     = 0.7,
    hsv_v     = 0.4,
    degrees   = 10.0,
    translate = 0.1,
    scale     = 0.5,
    fliplr    = 0.5,
    flipud    = 0.2,
    mosaic    = 0.5,
)

print("\n Training complete!")
# Out:
# New https://pypi.org/project/ultralytics/8.4.53 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.51  Python-3.10.11 torch-2.12.0+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/yolo_dataset/data.yaml, degrees=10.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.2, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=0.5, multi_scale=0.0, name=rice_leaf_detect, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../models/yolo, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 340.4398.4 MB/s, size: 89.4 KB)
# train: Scanning D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\labels\train.cache... 957 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 957/957  0.0s
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\20231006_165344.jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\20231006_165844.jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\20231006_165849.jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\20231006_165850.jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\Leaf_blast  (248).jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\Leaf_scald  (14).jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\Leaf_scald (30).jpg: corrupt JPEG restored and saved
# val: Fast image access  (ping: 0.10.0 ms, read: 112.263.7 MB/s, size: 11.4 KB)
# val: Scanning D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\labels\val.cache... 240 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 240/240  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.433      2.264       1.89         21        640: 100% ━━━━━━━━━━━━ 60/60 4.3s/it 4:154.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.2s/it 25.5s3.8ss
#                    all        240        267      0.637       0.36      0.447      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.475      1.868      1.913         24        640: 100% ━━━━━━━━━━━━ 60/60 4.2s/it 4:144.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.1s/it 24.9s3.7ss
#                    all        240        267      0.365      0.517       0.39      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.522      1.731      1.943         21        640: 100% ━━━━━━━━━━━━ 60/60 4.3s/it 4:153.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.1s/it 24.5s3.7ss
#                    all        240        267      0.595      0.528      0.562      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.513      1.588      1.961         23        640: 100% ━━━━━━━━━━━━ 60/60 4.3s/it 4:154.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.1s/it 24.6s3.7ss
#                    all        240        267      0.581      0.603       0.62      0.244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G      1.503      1.489      1.904         35        640: 100% ━━━━━━━━━━━━ 60/60 4.3s/it 4:164.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.1s/it 25.0s3.7ss
#                    all        240        267      0.613      0.551      0.587      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.495      1.469      1.931         29        640: 100% ━━━━━━━━━━━━ 60/60 4.3s/it 4:174.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.1s/it 24.6s3.7ss
#                    all        240        267      0.626      0.303      0.321       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G       1.43      1.393      1.868         32        640: 100% ━━━━━━━━━━━━ 60/60 4.3s/it 4:174.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.1s/it 24.7s3.7ss
#                    all        240        267      0.651      0.599      0.607      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G      1.385      1.331      1.806         29        640: 100% ━━━━━━━━━━━━ 60/60 4.3s/it 4:184.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.1s/it 24.6s3.7ss
#                    all        240        267      0.738      0.678      0.739       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G      1.393      1.308      1.809         29        640: 100% ━━━━━━━━━━━━ 60/60 4.3s/it 4:204.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.1s/it 24.8s3.7ss
#                    all        240        267      0
0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G     0.8265     0.6417       1.47         16        640: 100% ━━━━━━━━━━━━ 60/60 4.6s/it 4:334.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.2s/it 25.4s3.9ss
#                    all        240        267      0.888      0.783      0.876      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G     0.7984     0.6174      1.438         13        640: 100% ━━━━━━━━━━━━ 60/60 4.7s/it 4:414.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.4s/it 27.3s4.0ss
#                    all        240        267       0.89      0.798      0.882       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G     0.7804     0.6197      1.436         13        640: 100% ━━━━━━━━━━━━ 60/60 4.6s/it 4:374.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.3s/it 26.5s4.0ss
#                    all        240        267      0.895      0.802      0.884      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G     0.7713     0.6071      1.428         15        640: 100% ━━━━━━━━━━━━ 60/60 4.7s/it 4:414.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.3s/it 26.7s4.0ss
#                    all        240        267      0.928      0.794      0.888      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G      0.778     0.5922      1.432         14        640: 100% ━━━━━━━━━━━━ 60/60 4.6s/it 4:394.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.3s/it 26.5s4.0ss
#                    all        240        267      0.897      0.815      0.892      0.651
#
# 50 epochs completed in 3.980 hours.
# Optimizer stripped from D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect\weights\last.pt, 6.2MB
# Optimizer stripped from D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect\weights\best.pt, 6.2MB
#
# Validating D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect\weights\best.pt...
# Ultralytics 8.4.51  Python-3.10.11 torch-2.12.0+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.7s/it 22.0s3.3ss
#                    all        240        267      0.897      0.816      0.892      0.651
# Speed: 2.1ms preprocess, 82.1ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect
#
#  Training complete!

# %%
print(results.save_dir)
# Out:
# D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect

# %%
# 3. Đường dẫn model tốt nhất 
best_model_path = os.path.join(PROJECT_DIR, RUN_NAME, 'weights', 'best.pt')
print(f"Best model: {best_model_path}")
print(f"Exists    : {os.path.exists(best_model_path)}")
# Out:
# Best model: ../models/yolo\rice_leaf_detect\weights\best.pt
# Exists    : True

# %%
# 4. Validate
best_model = YOLO(best_model_path)
metrics = best_model.val(data=DATA_YAML)

print("\n" + "="*60)
print("VALIDATION METRICS")
print("="*60)
print(f"mAP50         : {metrics.box.map50:.4f}")
print(f"mAP50-95      : {metrics.box.map:.4f}")
print(f"Precision     : {metrics.box.mp:.4f}")
print(f"Recall        : {metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.4.51  Python-3.10.11 torch-2.12.0+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 534.2791.9 MB/s, size: 210.0 KB)
# val: Scanning D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\labels\val.cache... 240 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 240/240  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 1.3s/it 19.3s1.2s
#                    all        240        267      0.917      0.787      0.891      0.649
# Speed: 1.5ms preprocess, 72.1ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\detect\val
#
# ============================================================
# VALIDATION METRICS
# ============================================================
# mAP50         : 0.8909
# mAP50-95      : 0.6493
# Precision     : 0.9169
# Recall        : 0.7865

# %%
# 5. Hiển thị biểu đồ training 
results_dir = os.path.join(PROJECT_DIR, RUN_NAME)
plot_files = ['results.png', 'confusion_matrix.png', 'val_batch0_pred.jpg']

for plot_file in plot_files:
    path = os.path.join(results_dir, plot_file)
    if os.path.exists(path):
        img = mpimg.imread(path)
        plt.figure(figsize=(12, 6))
        plt.imshow(img)
        plt.title(plot_file)
        plt.axis('off')
        plt.show()
    else:
        print(f"  {plot_file} not found")

# %%
# 6. Export sang ONNX (optional - để dùng cross-platform)
# best_model.export(format='onnx')
# print("Exported to ONNX")

# 7. Copy best.pt ra thư mục models chính
import shutil
os.makedirs("../models", exist_ok=True)
dst = "../models/yolov8n_rice_leaf.pt"
shutil.copy(best_model_path, dst)
print(f" Saved best model -> {dst}")

print("\n READY for 10_apply_yolo_crop_all.ipynb")
# Out:
#  Saved best model -> ../models/yolov8s_rice_leaf.pt
#
#  READY for 10_apply_yolo_crop_all.ipynb
