# %%
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
# Out:
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# model = load_model("models/rice_disease_classifier.h5")
# print("Model loaded")
model = load_model("../models/rice_disease_classifier.h5")
print("Model loaded")
# Out:
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model loaded

# %%
DATA_DIR = "../data/split"

test_gen = ImageDataGenerator(rescale=1./255)

test_data = test_gen.flow_from_directory(
    os.path.join(DATA_DIR, "test"),
    target_size=(224, 224),
    batch_size=32,
    class_mode="categorical",
    shuffle=False   # ❗ rất quan trọng
)
# Out:
# Found 4353 images belonging to 9 classes.

# %%
loss, acc = model.evaluate(test_data)
print(f"Test accuracy: {acc:.4f}")
# Out:
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 137/137 [==============================] - 69s 498ms/step - loss: 0.6015 - accuracy: 0.8530
# Test accuracy: 0.8530

# %%
pred_probs = model.predict(test_data)
y_pred = np.argmax(pred_probs, axis=1)
y_true = test_data.classes
# Out:
# 137/137 [==============================] - 40s 286ms/step

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=test_data.class_indices.keys(),
    yticklabels=test_data.class_indices.keys()
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix – Rice Disease Classification")
plt.show()

# %%
class_names = list(test_data.class_indices.keys())

print(classification_report(
    y_true,
    y_pred,
    target_names=class_names
))
# Out:
#                         precision    recall  f1-score   support
#
#       bacterial_blight       0.89      0.88      0.89       608
# barrow_brown_leaf_spot       0.70      0.76      0.73       308
#             brown_spot       0.91      0.83      0.87       769
#                healthy       0.84      0.92      0.88       621
#             leaf_blast       0.88      0.76      0.81       756
#             leaf_scald       0.83      0.84      0.83       456
#              leaf_smut       0.89      0.94      0.91        50
#             rice_hispa       0.79      0.94      0.86       303
#          sheath_blight       0.87      0.92      0.90       482
#
#               accuracy                           0.85      4353
#              macro avg       0.84      0.87      0.85      4353
#           weighted avg       0.86      0.85      0.85      4353

# %%
import random

errors = np.where(y_pred != y_true)[0]

print("Số ảnh dự đoán sai:", len(errors))
# Out:
# Số ảnh dự đoán sai: 640

# %%
plt.figure(figsize=(12,8))

# for i, idx in enumerate(errors[:5]):
#     img, label = test_data[idx]
#     img = img[0]
#     true_label = class_names[y_true[idx]]
#     pred_label = class_names[y_pred[idx]]

#     plt.subplot(2,3,i+1)
#     plt.imshow(img)
#     plt.title(f"True: {true_label}\nPred: {pred_label}")
#     plt.axis("off")

batch_size = test_data.batch_size

for i, idx in enumerate(errors[:5]):
    batch_idx = idx // batch_size
    img_idx = idx % batch_size

    batch_imgs, batch_labels = test_data[batch_idx]
    img = batch_imgs[img_idx]
    label = batch_labels[img_idx]

    true_label = class_names[y_true[idx]]
    pred_label = class_names[y_pred[idx]]

    plt.subplot(2,3,i+1)
    plt.imshow(img)
    plt.title(f"True: {true_label}\nPred: {pred_label}")
    plt.axis("off")

plt.tight_layout()
plt.show()
