# %%
# import os
# os.environ["TF_USE_LEGACY_KERAS"] = "1"

# %%
# import tensorflow as tf
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
# from tensorflow.keras.applications import MobileNetV2
# import os

# import numpy as np
# from sklearn.utils.class_weight import compute_class_weight

# from tensorflow.keras.regularizers import l2
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# from tensorflow.keras.layers import BatchNormalization

import tensorflow as tf
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.applications import MobileNetV2
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
# Out:
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.15.0
# GPU available: []

# %%
# DATA_DIR = "data/split"
DATA_DIR = "../data/split"

IMG_SIZE = (224, 224)
BATCH_SIZE = 64
EPOCHS = 40

# %%
# train_gen = ImageDataGenerator(
#     rescale=1./255,
    
#     # Geometric transformations
#     rotation_range=40,           # 20 -> 40 (xoay mạnh hơn)
#     width_shift_range=0.2,       # 0.1 -> 0.2 (dịch ngang)
#     height_shift_range=0.2,      # 0.1 -> 0.2 (dịch dọc)
#     shear_range=0.2,             # (biến dạng)
#     zoom_range=0.3,              # 0.2 → 0.3 (zoom)
#     horizontal_flip=True,
#     vertical_flip=True,          # (lật dọc)
    
#     # Color/brightness augmentation
#     brightness_range=[0.7, 1.3], # Thay đổi độ sáng ±30%
#     fill_mode='nearest'          # Cách fill pixel khi transform
# )

# val_gen = ImageDataGenerator(rescale=1./255)

# val_gen = ImageDataGenerator(rescale=1./255)

# print(" Augmentation config:")
# print("  - Rotation: ±40°")
# print("  - Shift: ±20%")
# print("  - Zoom: ±30%")
# print("  - Brightness: ±30%")
# print("  - Flips: horizontal + vertical")

# Data đã augment offline -> Chỉ cần rescale
# print(" Using pre-augmented dataset")
# print("   -> Runtime augmentation: MINIMAL (chỉ flip)")

train_gen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,    #  Chỉ giữ flip (đơn giản, nhanh)
    #  Bỏ: rotation, shift, zoom, brightness
    # Lý do: Đã augment offline rồi, không cần augment mạnh runtime
    #  # Geometric
    # rotation_range=45,           # Tăng lên 45°
    # width_shift_range=0.25,      # Tăng lên 25%
    # height_shift_range=0.25,
    # shear_range=0.25,            # Thêm shear
    # zoom_range=0.25,
    # horizontal_flip=True,
    # vertical_flip=True,
    
    # # Color
    # brightness_range=[0.6, 1.4],  # Tăng range
    # fill_mode='nearest'
)

val_gen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_gen.flow_from_directory(
    os.path.join(DATA_DIR, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

val_data = val_gen.flow_from_directory(
    os.path.join(DATA_DIR, "val"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)
# Out:
# Found 20287 images belonging to 9 classes.
# Found 4347 images belonging to 9 classes.

# %%
# Đếm số samples mỗi class trong train set
class_counts = {}
for class_name, class_idx in train_data.class_indices.items():
    class_dir = os.path.join(DATA_DIR, "train", class_name)
    count = len([f for f in os.listdir(class_dir) if f.endswith(('.jpg', '.jpeg', '.png'))])
    class_counts[class_idx] = count

print("\n" + "="*70)
print("CLASS DISTRIBUTION (Training Set)")
print("="*70)

total_samples = sum(class_counts.values())
for class_name, class_idx in sorted(train_data.class_indices.items(), key=lambda x: x[1]):
    count = class_counts[class_idx]
    percentage = count / total_samples * 100
    bar = "█" * int(percentage / 2)  # Visual bar
    print(f"{class_name:25s}: {count:5d} ({percentage:5.1f}%) {bar}")

# Tính class weights tự động (cân bằng)
classes = np.array(list(class_counts.keys()))
samples = np.array(list(class_counts.values()))

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=np.repeat(classes, samples)
)

# Convert to dict
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

print("\n" + "="*70)
print("CLASS WEIGHTS (Higher = More Important)")
print("="*70)
for class_name, class_idx in sorted(train_data.class_indices.items(), key=lambda x: x[1]):
    weight = class_weight_dict[class_idx]
    stars = "x" * int(weight * 2)  # Visual indicator
    print(f"{class_name:25s}: {weight:6.3f} {stars}")

print("\n Classes với ít samples sẽ có weight cao hơn")
print("   -> Model sẽ chú ý nhiều hơn vào những class này khi training")
# Out:
# ======================================================================
# CLASS DISTRIBUTION (Training Set)
# ======================================================================
# bacterial_blight         :  2835 ( 14.0%) ██████
# barrow_brown_leaf_spot   :  1432 (  7.1%) ███
# brown_spot               :  3588 ( 17.7%) ████████
# healthy                  :  2894 ( 14.3%) ███████
# leaf_blast               :  3525 ( 17.4%) ████████
# leaf_scald               :  2125 ( 10.5%) █████
# leaf_smut                :   233 (  1.1%)
# rice_hispa               :  1411 (  7.0%) ███
# sheath_blight            :  2244 ( 11.1%) █████
#
# ======================================================================
# CLASS WEIGHTS (Higher = More Important)
# ======================================================================
# bacterial_blight         :  0.795 x
# barrow_brown_leaf_spot   :  1.574 xxx
# brown_spot               :  0.628 x
# healthy                  :  0.779 x
# leaf_blast               :  0.639 x
# leaf_scald               :  1.061 xx
# leaf_smut                :  9.674 xxxxxxxxxxxxxxxxxxx
# rice_hispa               :  1.598 xxx
# sheath_blight            :  1.005 xx
#
#  Classes với ít samples sẽ có weight cao hơn
#    -> Model sẽ chú ý nhiều hơn vào những class này khi training

# %%
print("Label mapping:")
print(train_data.class_indices)
# Out:
# Label mapping:
# {'bacterial_blight': 0, 'barrow_brown_leaf_spot': 1, 'brown_spot': 2, 'healthy': 3, 'leaf_blast': 4, 'leaf_scald': 5, 'leaf_smut': 6, 'rice_hispa': 7, 'sheath_blight': 8}

# %%
base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False
# Out:
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    # Dense(128, activation="relu"),
    # Dropout(0.3),
    Dense(128, activation="relu", kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(train_data.num_classes, activation="softmax")
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 2423625 (9.25 MB)
# Trainable params: 165385 (646.04 KB)
# Non-trainable params: 2258240 (8.61 MB)
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=7,
        restore_best_weights=True,  # tự restore về epoch tốt nhất
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-6,
        verbose=1
    ),
    ModelCheckpoint(
        "../models/rice_disease_best.keras",  # dùng .keras thay .h5
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# %%
# history = model.fit(
#     train_data,
#     validation_data=val_data,
#     epochs=EPOCHS
# )

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS,
    class_weight=class_weight_dict,
    callbacks=callbacks  
)

print("\n Training hoàn tất với class weights!")
# Out:
# Epoch 1/40
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 317/317 [==============================] - ETA: 0s - loss: 2.4523 - accuracy: 0.2760
# Epoch 1: val_accuracy improved from -inf to 0.50334, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 376s 1s/step - loss: 2.4523 - accuracy: 0.2760 - val_loss: 1.6589 - val_accuracy: 0.5033 - lr: 1.0000e-04
# Epoch 2/40
# 317/317 [==============================] - ETA: 0s - loss: 1.7353 - accuracy: 0.4462
# Epoch 2: val_accuracy improved from 0.50334 to 0.57580, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 206s 649ms/step - loss: 1.7353 - accuracy: 0.4462 - val_loss: 1.4442 - val_accuracy: 0.5758 - lr: 1.0000e-04
# Epoch 3/40
# 317/317 [==============================] - ETA: 0s - loss: 1.4938 - accuracy: 0.5197
# Epoch 3: val_accuracy improved from 0.57580 to 0.62572, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 213s 673ms/step - loss: 1.4938 - accuracy: 0.5197 - val_loss: 1.2991 - val_accuracy: 0.6257 - lr: 1.0000e-04
# Epoch 4/40
# 317/317 [==============================] - ETA: 0s - loss: 1.3604 - accuracy: 0.5704
# Epoch 4: val_accuracy improved from 0.62572 to 0.67150, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 228s 719ms/step - loss: 1.3604 - accuracy: 0.5704 - val_loss: 1.1937 - val_accuracy: 0.6715 - lr: 1.0000e-04
# Epoch 5/40
# 317/317 [==============================] - ETA: 0s - loss: 1.2488 - accuracy: 0.6003
# Epoch 5: val_accuracy improved from 0.67150 to 0.67932, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 222s 701ms/step - loss: 1.2488 - accuracy: 0.6003 - val_loss: 1.1312 - val_accuracy: 0.6793 - lr: 1.0000e-04
# Epoch 6/40
# 317/317 [==============================] - ETA: 0s - loss: 1.1814 - accuracy: 0.6258
# Epoch 6: val_accuracy improved from 0.67932 to 0.69772, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 229s 722ms/step - loss: 1.1814 - accuracy: 0.6258 - val_loss: 1.0913 - val_accuracy: 0.6977 - lr: 1.0000e-04
# Epoch 7/40
# 317/317 [==============================] - ETA: 0s - loss: 1.1065 - accuracy: 0.6482
# Epoch 7: val_accuracy improved from 0.69772 to 0.71475, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 245s 774ms/step - loss: 1.1065 - accuracy: 0.6482 - val_loss: 1.0344 - val_accuracy: 0.7147 - lr: 1.0000e-04
# Epoch 8/40
# 317/317 [==============================] - ETA: 0s - loss: 1.0632 - accuracy: 0.6684
# Epoch 8: val_accuracy improved from 0.71475 to 0.72970, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 229s 722ms/step - loss: 1.0632 - accuracy: 0.6684 - val_loss: 0.9975 - val_accuracy: 0.7297 - lr: 1.0000e-04
# Epoch 9/40
# 317/317 [==============================] - ETA: 0s - loss: 1.0181 - accuracy: 0.6807
# Epoch 9: val_accuracy improved from 0.72970 to 0.74235, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 227s 716ms/step - loss: 1.0181 - accuracy: 0.6807 - val_loss: 0.9585 - val_accuracy: 0.7424 - lr: 1.0000e-04
# Epoch 10/40
# 317/317 [==============================] - ETA: 0s - loss: 0.9761 - accuracy: 0.6976
# Epoch 10: val_accuracy improved from 0.74235 to 0.74488, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 225s 710ms/step - loss: 0.9761 - accuracy: 0.6976 - val_loss: 0.9445 - val_accuracy: 0.7449 - lr: 1.0000e-04
# Epoch 11/40
# 317/317 [==============================] - ETA: 0s - loss: 0.9351 - accuracy: 0.7137
# Epoch 11: val_accuracy improved from 0.74488 to 0.76398, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 228s 721ms/step - loss: 0.9351 - accuracy: 0.7137 - val_loss: 0.8990 - val_accuracy: 0.7640 - lr: 1.0000e-04
# Epoch 12/40
# 317/317 [==============================] - ETA: 0s - loss: 0.9071 - accuracy: 0.7223
# Epoch 12: val_accuracy improved from 0.76398 to 0.77019, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 226s 712ms/step - loss: 0.9071 - accuracy: 0.7223 - val_loss: 0.8801 - val_accuracy: 0.7702 - lr: 1.0000e-04
# Epoch 13/40
# 317/317 [==============================] - ETA: 0s - loss: 0.8824 - accuracy: 0.7296
# Epoch 13: val_accuracy improved from 0.77019 to 0.77893, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 212s 668ms/step - loss: 0.8824 - accuracy: 0.7296 - val_loss: 0.8571 - val_accuracy: 0.7789 - lr: 1.0000e-04
# Epoch 14/40
# 317/317 [==============================] - ETA: 0s - loss: 0.8443 - accuracy: 0.7430
# Epoch 14: val_accuracy improved from 0.77893 to 0.78169, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 229s 723ms/step - loss: 0.8443 - accuracy: 0.7430 - val_loss: 0.8480 - val_accuracy: 0.7817 - lr: 1.0000e-04
# Epoch 15/40
# 317/317 [==============================] - ETA: 0s - loss: 0.8219 - accuracy: 0.7514
# Epoch 15: val_accuracy did not improve from 0.78169
# 317/317 [==============================] - 235s 740ms/step - loss: 0.8219 - accuracy: 0.7514 - val_loss: 0.8277 - val_accuracy: 0.7815 - lr: 1.0000e-04
# Epoch 16/40
# 317/317 [==============================] - ETA: 0s - loss: 0.8092 - accuracy: 0.7597
# Epoch 16: val_accuracy improved from 0.78169 to 0.78215, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 254s 800ms/step - loss: 0.8092 - accuracy: 0.7597 - val_loss: 0.8167 - val_accuracy: 0.7821 - lr: 1.0000e-04
# Epoch 17/40
# 317/317 [==============================] - ETA: 0s - loss: 0.7703 - accuracy: 0.7673
# Epoch 17: val_accuracy improved from 0.78215 to 0.79089, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 239s 754ms/step - loss: 0.7703 - accuracy: 0.7673 - val_loss: 0.8024 - val_accuracy: 0.7909 - lr: 1.0000e-04
# Epoch 18/40
# 317/317 [==============================] - ETA: 0s - loss: 0.7533 - accuracy: 0.7749
# Epoch 18: val_accuracy improved from 0.79089 to 0.79618, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 212s 668ms/step - loss: 0.7533 - accuracy: 0.7749 - val_loss: 0.7819 - val_accuracy: 0.7962 - lr: 1.0000e-04
# Epoch 19/40
# 317/317 [==============================] - ETA: 0s - loss: 0.7498 - accuracy: 0.7727
# Epoch 19: val_accuracy improved from 0.79618 to 0.80078, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 207s 652ms/step - loss: 0.7498 - accuracy: 0.7727 - val_loss: 0.7659 - val_accuracy: 0.8008 - lr: 1.0000e-04
# Epoch 20/40
# 317/317 [==============================] - ETA: 0s - loss: 0.7220 - accuracy: 0.7851
# Epoch 20: val_accuracy did not improve from 0.80078
# 317/317 [==============================] - 206s 650ms/step - loss: 0.7220 - accuracy: 0.7851 - val_loss: 0.7651 - val_accuracy: 0.7980 - lr: 1.0000e-04
# Epoch 21/40
# 317/317 [==============================] - ETA: 0s - loss: 0.7116 - accuracy: 0.7887
# Epoch 21: val_accuracy improved from 0.80078 to 0.81412, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 207s 652ms/step - loss: 0.7116 - accuracy: 0.7887 - val_loss: 0.7295 - val_accuracy: 0.8141 - lr: 1.0000e-04
# Epoch 22/40
# 317/317 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.7937
# Epoch 22: val_accuracy improved from 0.81412 to 0.81458, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 207s 652ms/step - loss: 0.6940 - accuracy: 0.7937 - val_loss: 0.7234 - val_accuracy: 0.8146 - lr: 1.0000e-04
# Epoch 23/40
# 317/317 [==============================] - ETA: 0s - loss: 0.6753 - accuracy: 0.8009
# Epoch 23: val_accuracy did not improve from 0.81458
# 317/317 [==============================] - 206s 650ms/step - loss: 0.6753 - accuracy: 0.8009 - val_loss: 0.7149 - val_accuracy: 0.8144 - lr: 1.0000e-04
# Epoch 24/40
# 317/317 [==============================] - ETA: 0s - loss: 0.6640 - accuracy: 0.8036
# Epoch 24: val_accuracy did not improve from 0.81458
# 317/317 [==============================] - 208s 657ms/step - loss: 0.6640 - accuracy: 0.8036 - val_loss: 0.7077 - val_accuracy: 0.8141 - lr: 1.0000e-04
# Epoch 25/40
# 317/317 [==============================] - ETA: 0s - loss: 0.6498 - accuracy: 0.8042
# Epoch 25: val_accuracy improved from 0.81458 to 0.82586, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 206s 651ms/step - loss: 0.6498 - accuracy: 0.8042 - val_loss: 0.6932 - val_accuracy: 0.8259 - lr: 1.0000e-04
# Epoch 26/40
# 317/317 [==============================] - ETA: 0s - loss: 0.6334 - accuracy: 0.8132
# Epoch 26: val_accuracy improved from 0.82586 to 0.83161, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 205s 648ms/step - loss: 0.6334 - accuracy: 0.8132 - val_loss: 0.6813 - val_accuracy: 0.8316 - lr: 1.0000e-04
# Epoch 27/40
# 317/317 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.8159
# Epoch 27: val_accuracy improved from 0.83161 to 0.83207, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 206s 651ms/step - loss: 0.6214 - accuracy: 0.8159 - val_loss: 0.6694 - val_accuracy: 0.8321 - lr: 1.0000e-04
# Epoch 28/40
# 317/317 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.8185
# Epoch 28: val_accuracy improved from 0.83207 to 0.83667, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 206s 652ms/step - loss: 0.6152 - accuracy: 0.8185 - val_loss: 0.6687 - val_accuracy: 0.8367 - lr: 1.0000e-04
# Epoch 29/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5899 - accuracy: 0.8247
# Epoch 29: val_accuracy did not improve from 0.83667
# 317/317 [==============================] - 205s 646ms/step - loss: 0.5899 - accuracy: 0.8247 - val_loss: 0.6619 - val_accuracy: 0.8321 - lr: 1.0000e-04
# Epoch 30/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5771 - accuracy: 0.8295
# Epoch 30: val_accuracy did not improve from 0.83667
# 317/317 [==============================] - 205s 648ms/step - loss: 0.5771 - accuracy: 0.8295 - val_loss: 0.6462 - val_accuracy: 0.8355 - lr: 1.0000e-04
# Epoch 31/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5723 - accuracy: 0.8306
# Epoch 31: val_accuracy improved from 0.83667 to 0.83828, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 212s 670ms/step - loss: 0.5723 - accuracy: 0.8306 - val_loss: 0.6448 - val_accuracy: 0.8383 - lr: 1.0000e-04
# Epoch 32/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5684 - accuracy: 0.8299
# Epoch 32: val_accuracy improved from 0.83828 to 0.83943, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 202s 638ms/step - loss: 0.5684 - accuracy: 0.8299 - val_loss: 0.6285 - val_accuracy: 0.8394 - lr: 1.0000e-04
# Epoch 33/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5510 - accuracy: 0.8369
# Epoch 33: val_accuracy improved from 0.83943 to 0.84564, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 203s 640ms/step - loss: 0.5510 - accuracy: 0.8369 - val_loss: 0.6207 - val_accuracy: 0.8456 - lr: 1.0000e-04
# Epoch 34/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5423 - accuracy: 0.8411
# Epoch 34: val_accuracy did not improve from 0.84564
# 317/317 [==============================] - 201s 634ms/step - loss: 0.5423 - accuracy: 0.8411 - val_loss: 0.6277 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 35/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5294 - accuracy: 0.8449
# Epoch 35: val_accuracy did not improve from 0.84564
# 317/317 [==============================] - 201s 635ms/step - loss: 0.5294 - accuracy: 0.8449 - val_loss: 0.6165 - val_accuracy: 0.8422 - lr: 1.0000e-04
# Epoch 36/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5210 - accuracy: 0.8482
# Epoch 36: val_accuracy improved from 0.84564 to 0.84702, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 201s 635ms/step - loss: 0.5210 - accuracy: 0.8482 - val_loss: 0.6111 - val_accuracy: 0.8470 - lr: 1.0000e-04
# Epoch 37/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.8532
# Epoch 37: val_accuracy improved from 0.84702 to 0.84794, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 202s 637ms/step - loss: 0.5073 - accuracy: 0.8532 - val_loss: 0.6078 - val_accuracy: 0.8479 - lr: 1.0000e-04
# Epoch 38/40
# 317/317 [==============================] - ETA: 0s - loss: 0.5076 - accuracy: 0.8532
# Epoch 38: val_accuracy improved from 0.84794 to 0.84978, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 201s 635ms/step - loss: 0.5076 - accuracy: 0.8532 - val_loss: 0.6038 - val_accuracy: 0.8498 - lr: 1.0000e-04
# Epoch 39/40
# 317/317 [==============================] - ETA: 0s - loss: 0.4978 - accuracy: 0.8541
# Epoch 39: val_accuracy did not improve from 0.84978
# 317/317 [==============================] - 201s 634ms/step - loss: 0.4978 - accuracy: 0.8541 - val_loss: 0.6078 - val_accuracy: 0.8493 - lr: 1.0000e-04
# Epoch 40/40
# 317/317 [==============================] - ETA: 0s - loss: 0.4881 - accuracy: 0.8561
# Epoch 40: val_accuracy improved from 0.84978 to 0.85300, saving model to ../models\rice_disease_best.keras
# 317/317 [==============================] - 211s 666ms/step - loss: 0.4881 - accuracy: 0.8561 - val_loss: 0.5951 - val_accuracy: 0.8530 - lr: 1.0000e-04
#
#  Training hoàn tất với class weights!

# %%
# os.makedirs("models", exist_ok=True)

# model.save("models/rice_disease_classifier.h5")
# print(" Model saved!")

os.makedirs("../models", exist_ok=True)
# Lưu 3 format để phòng hờ
# Format 1: .keras (native Keras 3, ổn định nhất cho môi trường cùng version)
model.save("../models/rice_disease_classifier.keras")

# Format 2: SavedModel (ổn định nhất cross-version, dùng cho VPS)
model.export("../models/rice_disease_savedmodel")

# Format 3: .h5 giữ lại để backward compatible
model.save("../models/rice_disease_classifier.h5")

print("Saved: .keras, SavedModel, .h5")
# Out:
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# INFO:tensorflow:Assets written to: ../models/rice_disease_savedmodel\assets
# INFO:tensorflow:Assets written to: ../models/rice_disease_savedmodel\assets
# Saved artifact at '../models/rice_disease_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='mobilenetv2_1.00_224_input')
# Output Type:
#   TensorSpec(shape=(None, 9), dtype=tf.float32, name=None)
# Captures:
#   1322721701632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739238336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739239568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739240800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739242032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739236928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739247488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739247136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739252944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739249600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739243264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739247312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739764912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739767200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739762800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739764736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739770720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739771248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739772480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739773712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739771072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739768080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739761920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739942848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739775472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739762096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739244144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739770192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739772656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322721704624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322129178688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739776000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739945840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739947424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739945136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739944960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739942496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739952528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739953584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739954816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739944256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739955872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740040976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740042208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739954992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739766144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740041152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740047136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740047840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740042912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740051008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740048544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740044672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740045200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740053648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740046080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740054704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740155312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740159712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740158656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740048368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740163232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740163760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740164992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740166224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740156192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740162528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740156896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740302592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740163056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740162704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740305760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740308400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740309632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740310688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740303472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740307696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740314736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740315440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740305936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740308752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740301888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740433488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740436480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740314560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740317024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740437360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740442288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740443520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740314384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740160064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739763680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740051712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740052944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740170096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739943728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740306640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740157776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740439824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740302416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739951648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740441056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740446688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740447392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740434544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322739950768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740614592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740615472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740616704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740617936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740614416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740617584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740622512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740623568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740625328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740617232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740625856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740628848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740695808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740614768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740619872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740696160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740700912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740701616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740700560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740629200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740701792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740707248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740707776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740700384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740695456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740702848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740795696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740796928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740708304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740795520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740795872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740802032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740802736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740801680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740796048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740797984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740796576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740808896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740799216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740803968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740957952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740962352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740963584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740806256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740703728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740695984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740615824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740619520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740627616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740620752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740807312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740044848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740962704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740706544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740701968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740958480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740965872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740967104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740968160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740709888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740969568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740970624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740971856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740973088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740962528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740969744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741073344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741077216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741078448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741075104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741077040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741082496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741083728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741084960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741073696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741081088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741203712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741204944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741085312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741087776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741205296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741210224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741210752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741203184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741207760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741208640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741216560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741217792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741218848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741210928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741218320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741337776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741338480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741337424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741341648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741342528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741334256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741339536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741203008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741339360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741210400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741217616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741213920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741211632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740706368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741079328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740972032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740435072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741344288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740966400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741205120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741346048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741344992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741348864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741349040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741343584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741485232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741486464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741487696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741483120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741486112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741491568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741492800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741493856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741487872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741484000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741481888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741564336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741496496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740965344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741567328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741569968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741570672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741563632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741563456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741569792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741576480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741577184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741567504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741570320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741571376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741695232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741698400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741696288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741574368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741698576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741704032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741705264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741706496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741698224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741704912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741708960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741710192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741826304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741486992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741494736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741708784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741207056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741564688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741576656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322740442816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1322741564160: TensorSpec(shape=(), dtype=tf.resource, name=None)
# C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Saved: .keras, SavedModel, .h5

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.legend()
plt.title("Training Accuracy")
plt.show()
