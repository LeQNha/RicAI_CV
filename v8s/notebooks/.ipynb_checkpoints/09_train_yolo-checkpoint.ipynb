# %%
# Cài đặt ultralytics nếu chưa có
# !pip install ultralytics

# %%
import os
import torch
from pathlib import Path
from ultralytics import YOLO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Config
DATA_YAML   = "../data/yolo_dataset/data.yaml"
MODEL_SIZE  = "yolov8s.pt" 
EPOCHS      = 50
IMG_SIZE    = 640
BATCH_SIZE  = 16
PROJECT_DIR = "../models/yolo"
RUN_NAME    = "rice_leaf_detect"

print(f"Device : {'GPU ' + torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")
print(f"Data   : {os.path.abspath(DATA_YAML)}")
# Out:
# Device : CPU
# Data   : D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\data.yaml

# %%
# 1. Load pretrained YOLOv8n
model = YOLO(MODEL_SIZE)
print(f" Loaded {MODEL_SIZE}")
# Out:
#  Loaded yolov8s.pt

# %%
# FIX ID .TXT
BASE_LABEL_DIR = "../data/yolo_dataset/labels"

for split in ["train", "val", "test"]:
    label_dir = os.path.join(BASE_LABEL_DIR, split)
    
    if not os.path.exists(label_dir):
        continue
    
    for file in os.listdir(label_dir):
        path = os.path.join(label_dir, file)
        
        with open(path, "r") as f:
            lines = f.readlines()
        
        new_lines = []
        for line in lines:
            parts = line.strip().split()
            if len(parts) == 5:
                parts[0] = "0"  # fix class id
                new_lines.append(" ".join(parts))
        
        with open(path, "w") as f:
            f.write("\n".join(new_lines))

print(" Fixed ALL labels (train/val/test)")
# Out:
#  Fixed ALL labels (train/val/test)

# %%
# 2. Train
results = model.train(
    data      = DATA_YAML,
    epochs    = EPOCHS,
    imgsz     = IMG_SIZE,
    batch     = BATCH_SIZE,
    project   = PROJECT_DIR,
    name      = RUN_NAME,
    exist_ok  = True,
    patience  = 15,          # Early stopping
    save      = True,
    plots     = True,
    
    # Augmentation (nhẹ - ảnh đã augment)
    hsv_h     = 0.015,
    hsv_s     = 0.7,
    hsv_v     = 0.4,
    degrees   = 10.0,
    translate = 0.1,
    scale     = 0.5,
    fliplr    = 0.5,
    flipud    = 0.2,
    mosaic    = 0.5,
)

print("\n Training complete!")
# Out:
# New https://pypi.org/project/ultralytics/8.4.51 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37  Python-3.12.2 torch-2.3.1+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/yolo_dataset/data.yaml, degrees=10.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.2, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=0.5, multi_scale=0.0, name=rice_leaf_detect, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../models/yolo, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.20.1 ms, read: 10.718.6 MB/s, size: 89.4 KB)
# train: Scanning D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\labels\train.cache... 957 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 957/957  0.0s
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\20231006_165344.jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\20231006_165844.jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\20231006_165849.jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\20231006_165850.jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\Leaf_blast  (248).jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\Leaf_scald  (14).jpg: corrupt JPEG restored and saved
# train: D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\images\train\Leaf_scald (30).jpg: corrupt JPEG restored and saved
# val: Fast image access  (ping: 0.10.0 ms, read: 1.60.7 MB/s, size: 11.4 KB)
# val: Scanning D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\labels\val.cache... 240 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 240/240  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.525      2.133       1.95         21        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2510.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.7s/it 1:10<10.3ss
#                    all        240        267      0.384      0.513      0.322      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.662      1.625      2.039         24        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2310.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:09<10.2ss
#                    all        240        267      0.471      0.363      0.355      0.138
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.688      1.599      2.064         21        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2510.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:09<10.2ss
#                    all        240        267      0.482      0.352      0.345      0.136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.627      1.529      2.039         23        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2510.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:09<10.2ss
#                    all        240        267      0.256      0.303      0.142     0.0448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G      1.586      1.444      1.979         35        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2510.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.496      0.498      0.459      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.577      1.486      1.986         29        640: 100% ━━━━━━━━━━━━ 60/60 11.5s/it 11:2710.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:09<10.2ss
#                    all        240        267      0.433      0.375       0.31      0.113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G      1.501      1.406      1.928         32        640: 100% ━━━━━━━━━━━━ 60/60 12.0s/it 11:5811.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 9.2s/it 1:14<11.2ss
#                    all        240        267      0.484        0.6      0.539      0.244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G      1.445      1.349      1.856         29        640: 100% ━━━━━━━━━━━━ 60/60 11.5s/it 11:2710.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:08<10.2ss
#                    all        240        267      0.568      0.678       0.63      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G      1.446      1.354       1.85         29        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2110.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.724      0.638      0.667      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G      1.418      1.336      1.829         23        640: 100% ━━━━━━━━━━━━ 60/60 11.3s/it 11:1910.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.8s/it 1:10<10.5ss
#                    all        240        267      0.686      0.685      0.659      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G      1.435      1.314      1.861         22        640: 100% ━━━━━━━━━━━━ 60/60 11.5s/it 11:2710.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.742      0.562      0.682      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G      1.395      1.261      1.817         35        640: 100% ━━━━━━━━━━━━ 60/60 11.5s/it 11:3311.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.9s/it 1:11<10.5ss
#                    all        240        267      0.659      0.694      0.753      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G      1.342      1.217      1.771         26        640: 100% ━━━━━━━━━━━━ 60/60 11.6s/it 11:3611.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.9s/it 1:11<10.7ss
#                    all        240        267      0.703      0.655      0.689      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G      1.362      1.226      1.796         29        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2510.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.686      0.697      0.726      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G      1.313      1.216      1.721         24        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2110.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.757      0.704       0.74      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G      1.329      1.202      1.766         24        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2210.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.721      0.696      0.748      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G      1.295      1.224      1.732         30        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2310.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 9.0s/it 1:12<10.8ss
#                    all        240        267      0.721      0.707      0.769        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G      1.267      1.169      1.713         23        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:09<10.2ss
#                    all        240        267       0.69      0.727      0.742      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G      1.252      1.147      1.703         20        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.857      0.772      0.828      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G      1.251      1.132      1.677         22        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2610.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.7s/it 1:09<10.3ss
#                    all        240        267      0.844      0.742      0.831      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G      1.256      1.135      1.684         23        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:09<10.2ss
#                    all        240        267      0.806      0.701      0.787      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G      1.237      1.106      1.667         24        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2510.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.795      0.775      0.824      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G      1.222      1.103      1.666         26        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2510.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.901      0.746      0.807      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         0G      1.191      1.073      1.643         24        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.829      0.708      0.808      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50         0G      1.196      1.069      1.631         25        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2610.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.856       0.67      0.743      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50         0G      1.164      1.052      1.616         30        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:09<10.2ss
#                    all        240        267      0.849      0.777      0.837        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50         0G      1.171      1.035       1.63         21        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2310.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:09<10.3ss
#                    all        240        267      0.826      0.798      0.827      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50         0G      1.173      1.026      1.623         23        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.828      0.791      0.838      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50         0G      1.143      1.011      1.585         28        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.7s/it 1:09<10.4ss
#                    all        240        267      0.768      0.768      0.799       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G      1.144      1.007      1.612         22        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2510.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.764      0.753      0.794      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G       1.14     0.9851      1.603         36        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.887      0.734      0.823      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G      1.119     0.9869      1.589         27        640: 100% ━━━━━━━━━━━━ 60/60 11.5s/it 11:3110.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.7s/it 1:09<10.3ss
#                    all        240        267       0.84      0.787       0.83      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G      1.109     0.9703      1.571         30        640: 100% ━━━━━━━━━━━━ 60/60 11.5s/it 11:2810.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:08<10.2ss
#                    all        240        267      0.807       0.79      0.811      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G      1.112     0.9249       1.59         24        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2510.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:08<10.2ss
#                    all        240        267       0.85       0.76      0.827      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G      1.088     0.9425      1.581         29        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.848      0.792      0.857      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G      1.074     0.9418      1.546         19        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:09<10.2ss
#                    all        240        267      0.815      0.794      0.828       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G      1.076     0.9182      1.546         19        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:08<10.2ss
#                    all        240        267      0.826      0.768      0.828      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G      1.071     0.9113      1.546         21        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.874      0.778       0.86      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G      1.077     0.8953      1.537         29        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2310.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.6s/it 1:08<10.2ss
#                    all        240        267       0.87        0.8      0.869      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G      1.073      0.913      1.531         26        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.882      0.779      0.861       0.56
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G     0.9163     0.6911      1.545         15        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2210.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.859      0.783      0.842      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G     0.9116     0.6618      1.555         13        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2210.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.839      0.783      0.846      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G     0.9223     0.6637      1.541         13        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2210.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.892      0.774      0.854       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G     0.8605     0.6364      1.496         13        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.7s/it 1:09<10.3ss
#                    all        240        267      0.902       0.79      0.857      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G      0.881     0.6583      1.529         13        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.897      0.816      0.862      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G     0.8823     0.6403      1.517         16        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2210.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.2ss
#                    all        240        267      0.898      0.772       0.85      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G     0.8469     0.6268      1.483         13        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2410.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.885      0.805       0.86      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G     0.8513     0.6201      1.494         13        640: 100% ━━━━━━━━━━━━ 60/60 11.3s/it 11:1710.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.897       0.79      0.856      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G     0.8635     0.6262      1.493         15        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2210.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267       0.89      0.789      0.854      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G     0.8218     0.6045      1.466         14        640: 100% ━━━━━━━━━━━━ 60/60 11.4s/it 11:2110.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 8.5s/it 1:08<10.1ss
#                    all        240        267      0.888      0.798      0.854      0.594
#
# 50 epochs completed in 10.479 hours.
# Optimizer stripped from D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect\weights\last.pt, 22.5MB
# Optimizer stripped from D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect\weights\best.pt, 22.5MB
#
# Validating D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect\weights\best.pt...
# Ultralytics 8.4.37  Python-3.12.2 torch-2.3.1+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# Model summary (fused): 73 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 7.3s/it 58.2s8.6sss
#                    all        240        267      0.888      0.798      0.854      0.594
# Speed: 3.0ms preprocess, 232.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect
#
#  Training complete!

# %%
print(results.save_dir)
# Out:
# D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\models\yolo\rice_leaf_detect

# %%
# 3. Đường dẫn model tốt nhất 
best_model_path = os.path.join(PROJECT_DIR, RUN_NAME, 'weights', 'best.pt')
print(f"Best model: {best_model_path}")
print(f"Exists    : {os.path.exists(best_model_path)}")
# Out:
# Best model: ../models/yolo\rice_leaf_detect\weights\best.pt
# Exists    : True

# %%
# 4. Validate
best_model = YOLO(best_model_path)
metrics = best_model.val(data=DATA_YAML)

print("\n" + "="*60)
print("VALIDATION METRICS")
print("="*60)
print(f"mAP50         : {metrics.box.map50:.4f}")
print(f"mAP50-95      : {metrics.box.map:.4f}")
print(f"Precision     : {metrics.box.mp:.4f}")
print(f"Recall        : {metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.4.37  Python-3.12.2 torch-2.3.1+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# Model summary (fused): 73 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 21.141.5 MB/s, size: 210.0 KB)
# val: Scanning D:\Python Projects\RicAI_CV_main\ric_cv\data\yolo_dataset\labels\val.cache... 240 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 240/240  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 3.3s/it 49.3s3.2ss
#                    all        240        267      0.892      0.801      0.855      0.594
# Speed: 1.5ms preprocess, 191.0ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to D:\Python Projects\RicAI_CV_main\ric_cv\notebooks\runs\detect\val2
#
# ============================================================
# VALIDATION METRICS
# ============================================================
# mAP50         : 0.8552
# mAP50-95      : 0.5943
# Precision     : 0.8924
# Recall        : 0.8015

# %%
# 5. Hiển thị biểu đồ training 
results_dir = os.path.join(PROJECT_DIR, RUN_NAME)
plot_files = ['results.png', 'confusion_matrix.png', 'val_batch0_pred.jpg']

for plot_file in plot_files:
    path = os.path.join(results_dir, plot_file)
    if os.path.exists(path):
        img = mpimg.imread(path)
        plt.figure(figsize=(12, 6))
        plt.imshow(img)
        plt.title(plot_file)
        plt.axis('off')
        plt.show()
    else:
        print(f"  {plot_file} not found")

# %%
# 6. Export sang ONNX (optional - để dùng cross-platform)
# best_model.export(format='onnx')
# print("Exported to ONNX")

# 7. Copy best.pt ra thư mục models chính
import shutil
os.makedirs("../models", exist_ok=True)
dst = "../models/yolov8s_rice_leaf.pt"
shutil.copy(best_model_path, dst)
print(f" Saved best model -> {dst}")

print("\n READY for 10_apply_yolo_crop_all.ipynb")
# Out:
#  Saved best model -> ../models/yolov8s_rice_leaf.pt
#
#  READY for 10_apply_yolo_crop_all.ipynb
