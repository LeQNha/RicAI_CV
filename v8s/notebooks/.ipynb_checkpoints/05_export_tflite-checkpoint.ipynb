# %%
import tensorflow as tf
import os

# %%
# MODEL_PATH = "models/rice_disease_classifier.h5"
# model = tf.keras.models.load_model(MODEL_PATH)

# print(" Model loaded")

# MODEL_PATH = "../models/rice_disease_classifier.h5"
# model = tf.keras.models.load_model(MODEL_PATH)

import os
if os.path.exists("../models/rice_disease_classifier.keras"):
    model = tf.keras.models.load_model("../models/rice_disease_classifier.keras")
    print("Loaded from .keras")
elif os.path.exists("../models/rice_disease_savedmodel"):
    model = tf.keras.models.load_model("../models/rice_disease_savedmodel")
    print("Loaded from SavedModel")
else:
    model = tf.keras.models.load_model("../models/rice_disease_classifier.h5")
    print("Loaded from .h5")

print(" Model loaded")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#  Model loaded

# %%
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# Dùng cách này (ổn định hơn)
converter = tf.lite.TFLiteConverter.from_saved_model("../models/rice_disease_savedmodel")
tflite_model = converter.convert()

os.makedirs("models", exist_ok=True)

with open("../models/rice_disease_fp32.tflite", "wb") as f:
    f.write(tflite_model)

print(" Export FP32 TFLite done")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\qahhn\AppData\Local\Temp\tmpbjmwr69a\assets
# INFO:tensorflow:Assets written to: C:\Users\qahhn\AppData\Local\Temp\tmpbjmwr69a\assets
# Saved artifact at 'C:\Users\qahhn\AppData\Local\Temp\tmpbjmwr69a'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   2584852679952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852680528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852682256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852681872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852680720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852682448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852680912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852682832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852681104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852681680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852683216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852681488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852683792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852683600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852683024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852684368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852686864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852687248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852687056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852684176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852688400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852688784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852689168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852688976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852686288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852690320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852690704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852691088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852690896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852686480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852692240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852692816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852691472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852692624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852689936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584852685712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854676880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854677264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854677072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854676304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854677648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854678608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854678992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854678800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854678416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854680144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854680528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854680912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854680720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854676112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854682064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854682448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854682832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854682640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854675728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854683984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854684368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854684752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854684560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854679760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854685904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854686288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854686672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854686480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854681680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854687824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854688208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854688592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854688400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854683600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854689744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854690128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854690512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854690320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854685520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854691664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854687440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854889104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854691280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854689360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854890256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854890640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854891024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854890832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854889488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854892176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854892560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854892944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854892752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854888528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854894096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854894480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854894864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854894672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854889872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854896016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854896400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854896784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854896592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854891792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854897936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854898320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854898704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854898512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854893712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854899856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854900240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854900624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854900432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854895632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854901776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854902160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854902544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854902352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854897552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854903696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854903312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854901392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854904272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854899472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584854902928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855037136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855036560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855037328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855036368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855038672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855039056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855039440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855039248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855037520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855040592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855040976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855041360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855041168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855036176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855042512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855042896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855043280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855043088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855038288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855044432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855044816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855045200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855045008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855040208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855046352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855046736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855047120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855046928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855042128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855048272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855048656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855049040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855048848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855044048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855050192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855050576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855050960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855050768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855045968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855052112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855047888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871797392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855051728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584855049808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871798544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871798928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871799312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871799120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871797776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871800464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871800848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871801232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871801040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871797008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871802384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871802768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871803152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871802960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871798160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871804304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871804688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871805072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871804880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871800080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871806224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871806608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871806992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871806800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871802000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871808144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871808528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871808912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871808720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871803920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871810064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871810448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871810832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871810640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871805840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871811984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871811600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871809680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871812560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871807760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871811216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871978192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871977616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871978384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871977424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871979728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871980112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871980496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871980304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871978576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871981648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871982032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871982416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871982224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871977232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871983568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871983952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871984336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871984144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871979344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871985488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871985872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871986256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871986064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871981264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871987408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871987792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871988176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871987984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871983184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871989328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871989712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871990096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871989904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871985104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871991248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871991632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871992016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871991824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871987024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871993168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871988944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872206992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871992784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584871990864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872208144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872208528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872208912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872208720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872207376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872210064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872210448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872210832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872210640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872206608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872209296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872213136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872206800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872213712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872207760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872212944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872212560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2584872216016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#  Export FP32 TFLite done

# %%
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# converter.optimizations = [tf.lite.Optimize.DEFAULT]

# tflite_quant_model = converter.convert()

# with open("../models/rice_disease_quant.tflite", "wb") as f:
#     f.write(tflite_quant_model)

# print(" Export Quantized TFLite done")

# Tạo converter với config tương thích
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Chỉ định target_spec để tương thích với runtime cũ
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # Chỉ dùng ops chuẩn TFLite
]

#  Đảm bảo input/output là UINT8 (tương thích với tflite_flutter 0.10.1)
def representative_dataset():
    """Cung cấp dataset mẫu cho quantization"""
    import numpy as np
    for _ in range(100):
        yield [np.random.rand(1, 224, 224, 3).astype(np.float32)]

converter.representative_dataset = representative_dataset
converter.inference_input_type = tf.uint8   #  Input là UINT8
converter.inference_output_type = tf.uint8  #  Output là UINT8

# Convert
tflite_quant_model = converter.convert()

# Save
with open("../models/rice_disease_quant.tflite", "wb") as f:
    f.write(tflite_quant_model)

print(" Export Quantized TFLite (UINT8) done")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\qahhn\AppData\Local\Temp\tmpm8x4f7mt\assets
# INFO:tensorflow:Assets written to: C:\Users\qahhn\AppData\Local\Temp\tmpm8x4f7mt\assets
# Saved artifact at 'C:\Users\qahhn\AppData\Local\Temp\tmpm8x4f7mt'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 11), dtype=tf.float32, name=None)
# Captures:
#   1195482659344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195482659728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195482659152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195482660688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195482660112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195482659536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487872400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487871056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487872016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487871440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487872784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487872208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487873360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487873168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487872592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487873936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487876432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487876816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487876624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487873744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487877968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487878352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487878736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487878544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487875856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487879888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487880272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487880656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487880464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487876048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487881808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487882192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487882576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487882384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487877584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487882960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487883920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487884304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487884112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487883728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487884688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487885648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487886032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487885840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487885456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487887184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487881040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488084240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487886800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195487881424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488085776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488086160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488086544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488086352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488084432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488087696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488088080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488088464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488088272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488085008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488089616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488090000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488090384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488090192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488085392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488091536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488091920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488092304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488092112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488087312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488093456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488093840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488094224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488094032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488089232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488095376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488095760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488096144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488095952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488091152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488097296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488097680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488098064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488097872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488093072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488099216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488098832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488096912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488099792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488094992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488098448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488265424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488264272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488265616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488264464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488266960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488267344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488267728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488267536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488265808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488268880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488269264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488269648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488269456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488265040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488270800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488271184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488271568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488271376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488266576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488272720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488273104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488273488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488273296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488268496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488274640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488275024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488275408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488275216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488270416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488276560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488276944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488277328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488277136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488272336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488278480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488279248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488279056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488274256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488280400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488428688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488280016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488278096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488429840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488430224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488430608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488430416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488429072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488431760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488432144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488432528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488432336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488428112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488433680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488434064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488434448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488434256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488429456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488435600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488435984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488436368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488436176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488431376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488437520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488437904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488438288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488438096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488433296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488439440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488439824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488440208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488440016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488435216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488441360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488441744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488442128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488441936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488437136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488443280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488442896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488440976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488443856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488439056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488442512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488625872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488625296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488626064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488625104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488627408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488627792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488628176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488627984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488626256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488629328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488629712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488630096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488629904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488624912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488631248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488631632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488632016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488631824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488627024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488633168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488633552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488633936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488633744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488628944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488635088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488635472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488635856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488635664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488630864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488637008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488637392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488637776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488637584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488632784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488638928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488639312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488639696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488639504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488634704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488640848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488636624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488789136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488640464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488638544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488790288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488790672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488791056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488790864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488789520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488792208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488792592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488792976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488792784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488788752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488794128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488794512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488794896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488794704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488789904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488796048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488796432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488796816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488796624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488791824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488797968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488798352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488798736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488798544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488793744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488799888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488800272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488800656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488800464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488795664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488801808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488802192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488802576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488802384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488797584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488803728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488803344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488801424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488804304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195488799504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195484954896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195484956624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195484955088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195484957200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195484954704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195484956432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195484956048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1195484959504: TensorSpec(shape=(), dtype=tf.resource, name=None)
# C:\Users\qahhn\AppData\Roaming\Python\Python312\site-packages\tensorflow\lite\python\convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
#  Export Quantized TFLite (UINT8) done

# %%
fp32_size = os.path.getsize("../models/rice_disease_fp32.tflite") / (1024*1024)
quant_size = os.path.getsize("../models/rice_disease_quant.tflite") / (1024*1024)

print(f"FP32 size:  {fp32_size:.2f} MB")
print(f"Quant size: {quant_size:.2f} MB")
# Out:
# FP32 size:  9.08 MB
# Quant size: 2.75 MB

# %%
# import numpy as np
# import cv2

# # Load interpreter
# interpreter = tf.lite.Interpreter(model_path="../models/rice_disease_quant.tflite")
# interpreter.allocate_tensors()

# input_details = interpreter.get_input_details()
# output_details = interpreter.get_output_details()

# # Load 1 ảnh test
# img_path = "../data/split/test/brown_spot/" + os.listdir("../data/split/test/brown_spot")[0]
# img = cv2.imread(img_path)
# img = cv2.resize(img, (224,224))
# img = img / 255.0
# img = np.expand_dims(img, axis=0).astype(np.float32)

# # Run inference
# interpreter.set_tensor(input_details[0]['index'], img)
# interpreter.invoke()

# output = interpreter.get_tensor(output_details[0]['index'])
# print("Prediction:", output)
# print("Predicted class index:", np.argmax(output))

import numpy as np
import cv2

# Load interpreter
interpreter = tf.lite.Interpreter(model_path="../models/rice_disease_quant.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

#  In ra để kiểm tra input/output type
print("Input details:", input_details[0])
print("Output details:", output_details[0])

# Load 1 ảnh test
img_path = "../data/split/test/brown_spot/" + os.listdir("../data/split/test/brown_spot")[0]
img = cv2.imread(img_path)
img = cv2.resize(img, (224, 224))

#  THAY ĐỔI: KHÔNG chia 255, giữ nguyên UINT8
# img = img / 255.0  # XÓA dòng này
img = np.expand_dims(img, axis=0).astype(np.uint8)  # UINT8 thay vì FLOAT32

# Run inference
interpreter.set_tensor(input_details[0]['index'], img)
interpreter.invoke()

output = interpreter.get_tensor(output_details[0]['index'])
print("Raw output:", output)

# Convert output từ UINT8 → FLOAT32 để tính probability
output_float = output.astype(np.float32) / 255.0
print("Prediction (probabilities):", output_float)
print("Predicted class index:", np.argmax(output_float))
# Out:
# Input details: {'name': 'serving_default_input_layer_1:0', 'index': 0, 'shape': array([  1, 224, 224,   3]), 'shape_signature': array([ -1, 224, 224,   3]), 'dtype': <class 'numpy.uint8'>, 'quantization': (0.003921568859368563, 0), 'quantization_parameters': {'scales': array([0.00392157], dtype=float32), 'zero_points': array([0]), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# Output details: {'name': 'StatefulPartitionedCall_1:0', 'index': 177, 'shape': array([ 1, 11]), 'shape_signature': array([-1, 11]), 'dtype': <class 'numpy.uint8'>, 'quantization': (0.00390625, 0), 'quantization_parameters': {'scales': array([0.00390625], dtype=float32), 'zero_points': array([0]), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# Raw output: [[ 31   6  79 136   0   0   1   0   2   0   0]]
# Prediction (probabilities): [[0.12156863 0.02352941 0.30980393 0.53333336 0.         0.
#   0.00392157 0.         0.00784314 0.         0.        ]]
# Predicted class index: 3

# %%
labels = [
    "bacterial_blight",
    "barrow_brown_leaf_spot",
    "brown_spot",
    "healthy",
    "leaf_blast",
    "leaf_scald",
    "leaf_smut",
    "neck_blast",
    "rice_hispa",
    "sheath_blight"
    "tungro",
]

with open("../models/labels.txt", "w") as f:
    for label in labels:
        f.write(label + "\n")

print(" labels.txt saved")
# Out:
#  labels.txt saved
