# %%
# import os
# os.environ["TF_USE_LEGACY_KERAS"] = "1"

# %%
# import tensorflow as tf
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
# from tensorflow.keras.applications import MobileNetV2
# import os

# import numpy as np
# from sklearn.utils.class_weight import compute_class_weight

# from tensorflow.keras.regularizers import l2
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# from tensorflow.keras.layers import BatchNormalization

import tensorflow as tf
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.applications import MobileNetV2
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import os
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
# Out:
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.15.0
# GPU available: []

# %%
# DATA_DIR = "data/split"
DATA_DIR = "../data/split"

IMG_SIZE = (224, 224)
BATCH_SIZE = 64
EPOCHS = 40

# %%
# train_gen = ImageDataGenerator(
#     rescale=1./255,
    
#     # Geometric transformations
#     rotation_range=40,           # 20 -> 40 (xoay mạnh hơn)
#     width_shift_range=0.2,       # 0.1 -> 0.2 (dịch ngang)
#     height_shift_range=0.2,      # 0.1 -> 0.2 (dịch dọc)
#     shear_range=0.2,             # (biến dạng)
#     zoom_range=0.3,              # 0.2 → 0.3 (zoom)
#     horizontal_flip=True,
#     vertical_flip=True,          # (lật dọc)
    
#     # Color/brightness augmentation
#     brightness_range=[0.7, 1.3], # Thay đổi độ sáng ±30%
#     fill_mode='nearest'          # Cách fill pixel khi transform
# )

# val_gen = ImageDataGenerator(rescale=1./255)

# val_gen = ImageDataGenerator(rescale=1./255)

# print(" Augmentation config:")
# print("  - Rotation: ±40°")
# print("  - Shift: ±20%")
# print("  - Zoom: ±30%")
# print("  - Brightness: ±30%")
# print("  - Flips: horizontal + vertical")

# Data đã augment offline -> Chỉ cần rescale
# print(" Using pre-augmented dataset")
# print("   -> Runtime augmentation: MINIMAL (chỉ flip)")

train_gen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,    #  Chỉ giữ flip (đơn giản, nhanh)
    #  Bỏ: rotation, shift, zoom, brightness
    # Lý do: Đã augment offline rồi, không cần augment mạnh runtime
    #  # Geometric
    # rotation_range=45,           # Tăng lên 45°
    # width_shift_range=0.25,      # Tăng lên 25%
    # height_shift_range=0.25,
    # shear_range=0.25,            # Thêm shear
    # zoom_range=0.25,
    # horizontal_flip=True,
    # vertical_flip=True,
    
    # # Color
    # brightness_range=[0.6, 1.4],  # Tăng range
    # fill_mode='nearest'
)

val_gen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_gen.flow_from_directory(
    os.path.join(DATA_DIR, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

val_data = val_gen.flow_from_directory(
    os.path.join(DATA_DIR, "val"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)
# Out:
# Found 20120 images belonging to 9 classes.
# Found 4313 images belonging to 9 classes.

# %%
# Đếm số samples mỗi class trong train set
class_counts = {}
for class_name, class_idx in train_data.class_indices.items():
    class_dir = os.path.join(DATA_DIR, "train", class_name)
    count = len([f for f in os.listdir(class_dir) if f.endswith(('.jpg', '.jpeg', '.png'))])
    class_counts[class_idx] = count

print("\n" + "="*70)
print("CLASS DISTRIBUTION (Training Set)")
print("="*70)

total_samples = sum(class_counts.values())
for class_name, class_idx in sorted(train_data.class_indices.items(), key=lambda x: x[1]):
    count = class_counts[class_idx]
    percentage = count / total_samples * 100
    bar = "█" * int(percentage / 2)  # Visual bar
    print(f"{class_name:25s}: {count:5d} ({percentage:5.1f}%) {bar}")

# Tính class weights tự động (cân bằng)
classes = np.array(list(class_counts.keys()))
samples = np.array(list(class_counts.values()))

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=np.repeat(classes, samples)
)

# Convert to dict
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

print("\n" + "="*70)
print("CLASS WEIGHTS (Higher = More Important)")
print("="*70)
for class_name, class_idx in sorted(train_data.class_indices.items(), key=lambda x: x[1]):
    weight = class_weight_dict[class_idx]
    stars = "x" * int(weight * 2)  # Visual indicator
    print(f"{class_name:25s}: {weight:6.3f} {stars}")

print("\n Classes với ít samples sẽ có weight cao hơn")
print("   -> Model sẽ chú ý nhiều hơn vào những class này khi training")
# Out:
# ======================================================================
# CLASS DISTRIBUTION (Training Set)
# ======================================================================
# bacterial_blight         :  2808 ( 14.0%) ██████
# barrow_brown_leaf_spot   :  1407 (  7.0%) ███
# brown_spot               :  3569 ( 17.7%) ████████
# healthy                  :  2875 ( 14.3%) ███████
# leaf_blast               :  3497 ( 17.4%) ████████
# leaf_scald               :  2106 ( 10.5%) █████
# leaf_smut                :   216 (  1.1%)
# rice_hispa               :  1402 (  7.0%) ███
# sheath_blight            :  2240 ( 11.1%) █████
#
# ======================================================================
# CLASS WEIGHTS (Higher = More Important)
# ======================================================================
# bacterial_blight         :  0.796 x
# barrow_brown_leaf_spot   :  1.589 xxx
# brown_spot               :  0.626 x
# healthy                  :  0.778 x
# leaf_blast               :  0.639 x
# leaf_scald               :  1.062 xx
# leaf_smut                : 10.350 xxxxxxxxxxxxxxxxxxxx
# rice_hispa               :  1.595 xxx
# sheath_blight            :  0.998 x
#
#  Classes với ít samples sẽ có weight cao hơn
#    -> Model sẽ chú ý nhiều hơn vào những class này khi training

# %%
print("Label mapping:")
print(train_data.class_indices)
# Out:
# Label mapping:
# {'bacterial_blight': 0, 'barrow_brown_leaf_spot': 1, 'brown_spot': 2, 'healthy': 3, 'leaf_blast': 4, 'leaf_scald': 5, 'leaf_smut': 6, 'rice_hispa': 7, 'sheath_blight': 8}

# %%
base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False
# Out:
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    # Dense(128, activation="relu"),
    # Dropout(0.3),
    Dense(128, activation="relu", kernel_regularizer=l2(0.001)),
    BatchNormalization(), # mới
    Dropout(0.5),
    Dense(train_data.num_classes, activation="softmax")
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 2423625 (9.25 MB)
# Trainable params: 165385 (646.04 KB)
# Non-trainable params: 2258240 (8.61 MB)
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=7,
        restore_best_weights=True,  # tự restore về epoch tốt nhất
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-6,
        verbose=1
    ),
    ModelCheckpoint(
        "../models/rice_disease_best.keras",  # dùng .keras thay .h5
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# %%
# history = model.fit(
#     train_data,
#     validation_data=val_data,
#     epochs=EPOCHS
# )

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS,
    class_weight=class_weight_dict,
    callbacks=callbacks  
)

print("\n Training hoàn tất với class weights!")
# Out:
# Epoch 1/40
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 315/315 [==============================] - ETA: 0s - loss: 2.3845 - accuracy: 0.2867
# Epoch 1: val_accuracy improved from -inf to 0.47531, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 330s 1s/step - loss: 2.3845 - accuracy: 0.2867 - val_loss: 1.7311 - val_accuracy: 0.4753 - lr: 1.0000e-04
# Epoch 2/40
# 315/315 [==============================] - ETA: 0s - loss: 1.7442 - accuracy: 0.4347
# Epoch 2: val_accuracy improved from 0.47531 to 0.56504, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 249s 792ms/step - loss: 1.7442 - accuracy: 0.4347 - val_loss: 1.4688 - val_accuracy: 0.5650 - lr: 1.0000e-04
# Epoch 3/40
# 315/315 [==============================] - ETA: 0s - loss: 1.5134 - accuracy: 0.5062
# Epoch 3: val_accuracy improved from 0.56504 to 0.62625, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 249s 789ms/step - loss: 1.5134 - accuracy: 0.5062 - val_loss: 1.3112 - val_accuracy: 0.6262 - lr: 1.0000e-04
# Epoch 4/40
# 315/315 [==============================] - ETA: 0s - loss: 1.3724 - accuracy: 0.5533
# Epoch 4: val_accuracy improved from 0.62625 to 0.65082, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 621ms/step - loss: 1.3724 - accuracy: 0.5533 - val_loss: 1.2274 - val_accuracy: 0.6508 - lr: 1.0000e-04
# Epoch 5/40
# 315/315 [==============================] - ETA: 0s - loss: 1.2700 - accuracy: 0.5906
# Epoch 5: val_accuracy improved from 0.65082 to 0.69163, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 622ms/step - loss: 1.2700 - accuracy: 0.5906 - val_loss: 1.1324 - val_accuracy: 0.6916 - lr: 1.0000e-04
# Epoch 6/40
# 315/315 [==============================] - ETA: 0s - loss: 1.2038 - accuracy: 0.6168
# Epoch 6: val_accuracy improved from 0.69163 to 0.70415, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 197s 624ms/step - loss: 1.2038 - accuracy: 0.6168 - val_loss: 1.0791 - val_accuracy: 0.7042 - lr: 1.0000e-04
# Epoch 7/40
# 315/315 [==============================] - ETA: 0s - loss: 1.1299 - accuracy: 0.6417
# Epoch 7: val_accuracy improved from 0.70415 to 0.71922, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 622ms/step - loss: 1.1299 - accuracy: 0.6417 - val_loss: 1.0281 - val_accuracy: 0.7192 - lr: 1.0000e-04
# Epoch 8/40
# 315/315 [==============================] - ETA: 0s - loss: 1.0829 - accuracy: 0.6559
# Epoch 8: val_accuracy improved from 0.71922 to 0.72734, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 195s 621ms/step - loss: 1.0829 - accuracy: 0.6559 - val_loss: 1.0190 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 9/40
# 315/315 [==============================] - ETA: 0s - loss: 1.0348 - accuracy: 0.6763
# Epoch 9: val_accuracy improved from 0.72734 to 0.74380, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 621ms/step - loss: 1.0348 - accuracy: 0.6763 - val_loss: 0.9602 - val_accuracy: 0.7438 - lr: 1.0000e-04
# Epoch 10/40
# 315/315 [==============================] - ETA: 0s - loss: 0.9964 - accuracy: 0.6891
# Epoch 10: val_accuracy improved from 0.74380 to 0.74890, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 198s 630ms/step - loss: 0.9964 - accuracy: 0.6891 - val_loss: 0.9380 - val_accuracy: 0.7489 - lr: 1.0000e-04
# Epoch 11/40
# 315/315 [==============================] - ETA: 0s - loss: 0.9547 - accuracy: 0.7027
# Epoch 11: val_accuracy improved from 0.74890 to 0.76675, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 197s 624ms/step - loss: 0.9547 - accuracy: 0.7027 - val_loss: 0.9032 - val_accuracy: 0.7668 - lr: 1.0000e-04
# Epoch 12/40
# 315/315 [==============================] - ETA: 0s - loss: 0.9271 - accuracy: 0.7140
# Epoch 12: val_accuracy improved from 0.76675 to 0.77000, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 622ms/step - loss: 0.9271 - accuracy: 0.7140 - val_loss: 0.8785 - val_accuracy: 0.7700 - lr: 1.0000e-04
# Epoch 13/40
# 315/315 [==============================] - ETA: 0s - loss: 0.8953 - accuracy: 0.7234
# Epoch 13: val_accuracy improved from 0.77000 to 0.77324, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 198s 628ms/step - loss: 0.8953 - accuracy: 0.7234 - val_loss: 0.8651 - val_accuracy: 0.7732 - lr: 1.0000e-04
# Epoch 14/40
# 315/315 [==============================] - ETA: 0s - loss: 0.8707 - accuracy: 0.7312
# Epoch 14: val_accuracy improved from 0.77324 to 0.78437, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 624ms/step - loss: 0.8707 - accuracy: 0.7312 - val_loss: 0.8218 - val_accuracy: 0.7844 - lr: 1.0000e-04
# Epoch 15/40
# 315/315 [==============================] - ETA: 0s - loss: 0.8405 - accuracy: 0.7422
# Epoch 15: val_accuracy did not improve from 0.78437
# 315/315 [==============================] - 196s 623ms/step - loss: 0.8405 - accuracy: 0.7422 - val_loss: 0.8244 - val_accuracy: 0.7818 - lr: 1.0000e-04
# Epoch 16/40
# 315/315 [==============================] - ETA: 0s - loss: 0.8225 - accuracy: 0.7444
# Epoch 16: val_accuracy improved from 0.78437 to 0.79202, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 201s 639ms/step - loss: 0.8225 - accuracy: 0.7444 - val_loss: 0.8078 - val_accuracy: 0.7920 - lr: 1.0000e-04
# Epoch 17/40
# 315/315 [==============================] - ETA: 0s - loss: 0.7992 - accuracy: 0.7547
# Epoch 17: val_accuracy improved from 0.79202 to 0.79759, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 205s 652ms/step - loss: 0.7992 - accuracy: 0.7547 - val_loss: 0.7763 - val_accuracy: 0.7976 - lr: 1.0000e-04
# Epoch 18/40
# 315/315 [==============================] - ETA: 0s - loss: 0.7700 - accuracy: 0.7645
# Epoch 18: val_accuracy improved from 0.79759 to 0.80849, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 623ms/step - loss: 0.7700 - accuracy: 0.7645 - val_loss: 0.7513 - val_accuracy: 0.8085 - lr: 1.0000e-04
# Epoch 19/40
# 315/315 [==============================] - ETA: 0s - loss: 0.7671 - accuracy: 0.7674
# Epoch 19: val_accuracy improved from 0.80849 to 0.81127, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 195s 620ms/step - loss: 0.7671 - accuracy: 0.7674 - val_loss: 0.7470 - val_accuracy: 0.8113 - lr: 1.0000e-04
# Epoch 20/40
# 315/315 [==============================] - ETA: 0s - loss: 0.7399 - accuracy: 0.7743
# Epoch 20: val_accuracy did not improve from 0.81127
# 315/315 [==============================] - 195s 618ms/step - loss: 0.7399 - accuracy: 0.7743 - val_loss: 0.7290 - val_accuracy: 0.8103 - lr: 1.0000e-04
# Epoch 21/40
# 315/315 [==============================] - ETA: 0s - loss: 0.7255 - accuracy: 0.7802
# Epoch 21: val_accuracy improved from 0.81127 to 0.81822, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 195s 619ms/step - loss: 0.7255 - accuracy: 0.7802 - val_loss: 0.7215 - val_accuracy: 0.8182 - lr: 1.0000e-04
# Epoch 22/40
# 315/315 [==============================] - ETA: 0s - loss: 0.7128 - accuracy: 0.7873
# Epoch 22: val_accuracy improved from 0.81822 to 0.81985, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 195s 620ms/step - loss: 0.7128 - accuracy: 0.7873 - val_loss: 0.7149 - val_accuracy: 0.8198 - lr: 1.0000e-04
# Epoch 23/40
# 315/315 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.7930
# Epoch 23: val_accuracy improved from 0.81985 to 0.82101, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 623ms/step - loss: 0.6940 - accuracy: 0.7930 - val_loss: 0.7056 - val_accuracy: 0.8210 - lr: 1.0000e-04
# Epoch 24/40
# 315/315 [==============================] - ETA: 0s - loss: 0.6748 - accuracy: 0.7985
# Epoch 24: val_accuracy did not improve from 0.82101
# 315/315 [==============================] - 198s 628ms/step - loss: 0.6748 - accuracy: 0.7985 - val_loss: 0.7063 - val_accuracy: 0.8166 - lr: 1.0000e-04
# Epoch 25/40
# 315/315 [==============================] - ETA: 0s - loss: 0.6614 - accuracy: 0.7990
# Epoch 25: val_accuracy improved from 0.82101 to 0.83028, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 622ms/step - loss: 0.6614 - accuracy: 0.7990 - val_loss: 0.6726 - val_accuracy: 0.8303 - lr: 1.0000e-04
# Epoch 26/40
# 315/315 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.8068
# Epoch 26: val_accuracy improved from 0.83028 to 0.83353, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 197s 626ms/step - loss: 0.6392 - accuracy: 0.8068 - val_loss: 0.6666 - val_accuracy: 0.8335 - lr: 1.0000e-04
# Epoch 27/40
# 315/315 [==============================] - ETA: 0s - loss: 0.6286 - accuracy: 0.8106
# Epoch 27: val_accuracy did not improve from 0.83353
# 315/315 [==============================] - 195s 620ms/step - loss: 0.6286 - accuracy: 0.8106 - val_loss: 0.6735 - val_accuracy: 0.8307 - lr: 1.0000e-04
# Epoch 28/40
# 315/315 [==============================] - ETA: 0s - loss: 0.6217 - accuracy: 0.8136
# Epoch 28: val_accuracy improved from 0.83353 to 0.84605, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 623ms/step - loss: 0.6217 - accuracy: 0.8136 - val_loss: 0.6392 - val_accuracy: 0.8460 - lr: 1.0000e-04
# Epoch 29/40
# 315/315 [==============================] - ETA: 0s - loss: 0.6057 - accuracy: 0.8212
# Epoch 29: val_accuracy did not improve from 0.84605
# 315/315 [==============================] - 195s 620ms/step - loss: 0.6057 - accuracy: 0.8212 - val_loss: 0.6256 - val_accuracy: 0.8403 - lr: 1.0000e-04
# Epoch 30/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5978 - accuracy: 0.8212
# Epoch 30: val_accuracy did not improve from 0.84605
# 315/315 [==============================] - 194s 617ms/step - loss: 0.5978 - accuracy: 0.8212 - val_loss: 0.6416 - val_accuracy: 0.8423 - lr: 1.0000e-04
# Epoch 31/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5899 - accuracy: 0.8219
# Epoch 31: val_accuracy did not improve from 0.84605
# 315/315 [==============================] - 194s 617ms/step - loss: 0.5899 - accuracy: 0.8219 - val_loss: 0.6237 - val_accuracy: 0.8405 - lr: 1.0000e-04
# Epoch 32/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5855 - accuracy: 0.8250
# Epoch 32: val_accuracy improved from 0.84605 to 0.84813, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 198s 629ms/step - loss: 0.5855 - accuracy: 0.8250 - val_loss: 0.6219 - val_accuracy: 0.8481 - lr: 1.0000e-04
# Epoch 33/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5695 - accuracy: 0.8279
# Epoch 33: val_accuracy improved from 0.84813 to 0.84837, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 208s 661ms/step - loss: 0.5695 - accuracy: 0.8279 - val_loss: 0.6034 - val_accuracy: 0.8484 - lr: 1.0000e-04
# Epoch 34/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5583 - accuracy: 0.8363
# Epoch 34: val_accuracy improved from 0.84837 to 0.85486, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 197s 625ms/step - loss: 0.5583 - accuracy: 0.8363 - val_loss: 0.6012 - val_accuracy: 0.8549 - lr: 1.0000e-04
# Epoch 35/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5456 - accuracy: 0.8400
# Epoch 35: val_accuracy did not improve from 0.85486
# 315/315 [==============================] - 196s 621ms/step - loss: 0.5456 - accuracy: 0.8400 - val_loss: 0.5922 - val_accuracy: 0.8546 - lr: 1.0000e-04
# Epoch 36/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5372 - accuracy: 0.8396
# Epoch 36: val_accuracy did not improve from 0.85486
# 315/315 [==============================] - 195s 619ms/step - loss: 0.5372 - accuracy: 0.8396 - val_loss: 0.5833 - val_accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 37/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5302 - accuracy: 0.8423
# Epoch 37: val_accuracy improved from 0.85486 to 0.85625, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 196s 622ms/step - loss: 0.5302 - accuracy: 0.8423 - val_loss: 0.5736 - val_accuracy: 0.8562 - lr: 1.0000e-04
# Epoch 38/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5257 - accuracy: 0.8427
# Epoch 38: val_accuracy did not improve from 0.85625
# 315/315 [==============================] - 197s 626ms/step - loss: 0.5257 - accuracy: 0.8427 - val_loss: 0.5908 - val_accuracy: 0.8518 - lr: 1.0000e-04
# Epoch 39/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5206 - accuracy: 0.8465
# Epoch 39: val_accuracy improved from 0.85625 to 0.86019, saving model to ../models\rice_disease_best.keras
# 315/315 [==============================] - 197s 625ms/step - loss: 0.5206 - accuracy: 0.8465 - val_loss: 0.5682 - val_accuracy: 0.8602 - lr: 1.0000e-04
# Epoch 40/40
# 315/315 [==============================] - ETA: 0s - loss: 0.5013 - accuracy: 0.8533
# Epoch 40: val_accuracy did not improve from 0.86019
# 315/315 [==============================] - 196s 621ms/step - loss: 0.5013 - accuracy: 0.8533 - val_loss: 0.5762 - val_accuracy: 0.8523 - lr: 1.0000e-04
#
#  Training hoàn tất với class weights!

# %%
# os.makedirs("models", exist_ok=True)

# model.save("models/rice_disease_classifier.h5")
# print(" Model saved!")

os.makedirs("../models", exist_ok=True)
# Lưu 3 format để phòng hờ
# Format 1: .keras (native Keras 3, ổn định nhất cho môi trường cùng version)
model.save("../models/rice_disease_classifier.keras")

# Format 2: SavedModel (ổn định nhất cross-version, dùng cho VPS)
model.export("../models/rice_disease_savedmodel")

# Format 3: .h5 giữ lại để backward compatible
model.save("../models/rice_disease_classifier.h5")

print("Saved: .keras, SavedModel, .h5")
# Out:
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# WARNING:absl:`mobilenetv2_1.00_224_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_224_input`.
# INFO:tensorflow:Assets written to: ../models/rice_disease_savedmodel\assets
# INFO:tensorflow:Assets written to: ../models/rice_disease_savedmodel\assets
# Saved artifact at '../models/rice_disease_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='mobilenetv2_1.00_224_input')
# Output Type:
#   TensorSpec(shape=(None, 9), dtype=tf.float32, name=None)
# Captures:
#   1540772871184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773599664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773600896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773602128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773603360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773604240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773607936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773597376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773604768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773604416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773596672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774232128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774238112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774239696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774235296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774233712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774243216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774243744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774244976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774246208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774241280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774244624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774242688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774431200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774242512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774246032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774428736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774438416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774436304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774437360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774434016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774440176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774442992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774444224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774593104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774438240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774438064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774593456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774598736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774600496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774593280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774594160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774604016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774605248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774606304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774595744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774595040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774757824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774758528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774757472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774604544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774763280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774758176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774761696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774762224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774758000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774756592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774766272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774771904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774765568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774756768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774888896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774890832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774892064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774893296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774890656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774895232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774889600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774766624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774771728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774595920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774599792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774247616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774430320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540772103616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774767680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540773605648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774435424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774896992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774603840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540772871360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774433136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774895760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774898752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774889424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774767152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774897520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774903328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774954432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774899280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774894176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774893824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774955488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774960768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774953376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774967456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774956016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774963936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774966576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774968864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774964464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775054496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775053264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775055200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775057488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774958128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775057840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775061536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775062064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775061712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774960416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775061008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775063296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775166896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775063472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775055024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775169888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775172528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775173232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775168128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775168832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775169008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775178864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775179568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775173936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775065232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775174288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775297440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775300784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775298672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775177456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775300960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775177632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775180096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775179920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540772869600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775067168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774953728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774964816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774889776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540774763632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775056784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775298320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775306416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775305008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775066816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775303776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775309760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775310464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775301488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775305360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775307824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775447360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775448064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775447008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775310112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775298144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775446304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775454400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775452288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775445424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775449648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775460032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775559232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775449472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775449296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775561872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775563280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775564512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775565744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775563104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775566096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775562576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775571376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775573136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775565040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775573664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775691536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775692240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775569616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775691360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775692768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775697872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775698576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775697520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775691888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775701392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775691712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775705088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775702976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775695936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775692416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775858368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775696640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775700512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775562928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775702272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775453872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775459856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775451584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775052032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775458096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775298848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775855904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775575248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775301840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775862240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775857136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775863472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775856432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775448944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775866464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775867520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775868752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775869984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775862592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775864352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798940784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798944128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798942016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775311344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798943072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798949760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798950464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798941840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798943952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798948704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799070976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799071680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798947296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798954160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798953456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799072912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799078016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799075904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799070624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799072560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799083648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799084352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799072208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799077840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799081712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799205040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799205744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799204688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799084000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799209616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799203984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799212080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799209968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799202928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799207328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799381744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799214016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799207152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799216656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799086112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799077488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540799075024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798942720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540772110656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798950992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775455808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540798940608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775861360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775858544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775866288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1540775452640: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved: .keras, SavedModel, .h5
# C:\Users\qahhn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.legend()
plt.title("Training Accuracy")
plt.show()
